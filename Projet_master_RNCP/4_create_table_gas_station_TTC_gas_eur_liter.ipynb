# %%
import pandas as pd
import warnings
import pymongo
from datetime import datetime

pd.options.mode.chained_assignment = None
warnings.filterwarnings('ignore', category=RuntimeWarning)

# Setup MongoDB connection (local)
mongo_host = "localhost"
mongo_port = 27017
mongo_user = "admin"
mongo_password = "password"
auth_db = "admin"
client_mongo = pymongo.MongoClient(
    host=mongo_host,
    port=mongo_port,
    username=mongo_user,
    password=mongo_password,
    authSource=auth_db
)
db_mongo_denorm = client_mongo.get_database("denormalization")
db_mongo_denorm.drop_collection("station_ttc_gas_eur_liter")

db_mongo_datalake = client_mongo.get_database("datalake")

# ALL YEARS
years = ['2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022', '2023', '2024', '2025']
#years = ['2007', '2008', '2009', '2010', '2011', '2012']
# ONE YEAR
# years = ['2008']

for year in years:
    year = int(year)
    print("YEAR: ", year, " // start_date:", datetime(year, 1, 1), "end_date:", datetime(year+1, 1, 1))
    
    # --- collection french_gas_station ----
    collection_mongo = db_mongo_datalake.get_collection("french_gas_station_price_logs_eur")
    cursor = collection_mongo.find(
        {
            "Date": {"$gte": datetime(year, 1, 1), "$lt": datetime(year+1, 1, 1)}
        },
        {
            "_id": 0, "Id_station_essence": 1, "Date": 1, "Nom": 1, "Valeur": 1
        }
    )
    df_french_gas_station = pd.DataFrame(list(cursor))

    df_french_gas_station['Date'] = pd.to_datetime(df_french_gas_station['Date'])
    df_french_gas_station = df_french_gas_station.rename(columns={
        "Id_station_essence": "Gas_station_id", "Nom": "Gas_name", "Valeur": "Gas_eur_liter"
    })
    # Combine the gas station prices when same date and same gas name (by mean)
    df_station_ttc_gas_eur_liter = df_french_gas_station.groupby(['Date', 'Gas_name'], as_index=False)['Gas_eur_liter'].mean().round(5)
    
    # Create col for each gas_name (pivot rotate df)
    df_station_ttc_gas_eur_liter = df_station_ttc_gas_eur_liter.pivot(index='Date', columns='Gas_name', values='Gas_eur_liter')
    df_station_ttc_gas_eur_liter = df_station_ttc_gas_eur_liter.rename(
        columns=lambda x: f"station_ttc_{x.upper()}_eur_liter").reset_index()
#     print("df_station_ttc_gas_eur_liter\n", df_station_ttc_gas_eur_liter)
    
    # always have all existing columns
    all_fuel_name_existing = [
        "station_ttc_E10_eur_liter",
        "station_ttc_E85_eur_liter",
        "station_ttc_GPLC_eur_liter",
        "station_ttc_GAZOLE_eur_liter",
        "station_ttc_SP95_eur_liter",
        "station_ttc_SP98_eur_liter"
    ]
    for col in all_fuel_name_existing:
        if col not in df_station_ttc_gas_eur_liter.columns:
            df_station_ttc_gas_eur_liter[col] = float('nan')
    
    print("df_station_ttc_gas_eur_liter\n", df_station_ttc_gas_eur_liter.head())
    
    # ----- Push to MongoDB -----
    collection_mongo = db_mongo_denorm.get_collection("station_ttc_gas_eur_liter")
    collection_mongo.create_index([("Date", pymongo.ASCENDING)])

    records = df_station_ttc_gas_eur_liter.to_dict(orient="records")
    collection_mongo.insert_many(records)
    print("correctly loaded", year," df_station_ttc_gas_eur_liter to denormalized collection MongoDB")
# Out:
# YEAR:  2007  // start_date: 2007-01-01 00:00:00 end_date: 2008-01-01 00:00:00
# df_station_ttc_gas_eur_liter
#  Gas_name       Date  station_ttc_E85_eur_liter  station_ttc_GPLC_eur_liter  \
# 0        2007-01-01                        NaN                         NaN
# 1        2007-01-02                        NaN                         NaN
# 2        2007-01-03                        NaN                         NaN
# 3        2007-01-04                        NaN                         NaN
# 4        2007-01-05                        NaN                         NaN
#
# Gas_name  station_ttc_GAZOLE_eur_liter  station_ttc_SP95_eur_liter  \
# 0                              1.10647                     1.24179
# 1                              1.00571                     1.17889
# 2                              1.00645                     1.18080
# 3                              1.02514                     1.18936
# 4                              1.00072                     1.17936
#
# Gas_name  station_ttc_E10_eur_liter  station_ttc_SP98_eur_liter
# 0                               NaN                         NaN
# 1                               NaN                         NaN
# 2                               NaN                         NaN
# 3                               NaN                         NaN
# 4                               NaN                         NaN
# correctly loaded 2007  df_station_ttc_gas_eur_liter to denormalized collection MongoDB
# YEAR:  2008  // start_date: 2008-01-01 00:00:00 end_date: 2009-01-01 00:00:00
# df_station_ttc_gas_eur_liter
#  Gas_name       Date  station_ttc_E85_eur_liter  station_ttc_GPLC_eur_liter  \
# 0        2008-01-01                    0.82000                     0.76720
# 1        2008-01-02                    0.80577                     0.72946
# 2        2008-01-03                    0.81065                     0.74724
# 3        2008-01-04                    0.81141                     0.73195
# 4        2008-01-05                    0.80834                     0.73563
#
# Gas_name  station_ttc_GAZOLE_eur_liter  station_ttc_SP95_eur_liter  \
# 0                              1.25893                     1.38413
# 1                              1.19713                     1.35771
# 2                              1.20087                     1.36717
# 3                              1.20449                     1.36928
# 4                              1.20261                     1.36844
#
# Gas_name  station_ttc_E10_eur_liter  station_ttc_SP98_eur_liter
# 0                               NaN                         NaN
# 1                               NaN                         NaN
# 2                               NaN                         NaN
# 3                               NaN                         NaN
# 4                               NaN                         NaN
# correctly loaded 2008  df_station_ttc_gas_eur_liter to denormalized collection MongoDB
# YEAR:  2009  // start_date: 2009-01-01 00:00:00 end_date: 2010-01-01 00:00:00
# df_station_ttc_gas_eur_liter
#  Gas_name       Date  station_ttc_E10_eur_liter  station_ttc_E85_eur_liter  \
# 0        2009-01-01                        NaN                        NaN
# 1        2009-01-02                        NaN                    0.83753
# 2        2009-01-03                        NaN                    0.83622
# 3        2009-01-04                        NaN                    0.84833
# 4        2009-01-05                        NaN                    0.83705
#
# Gas_name  station_ttc_GPLC_eur_liter  station_ttc_GAZOLE_eur_liter  \
# 0                            0.69737                       0.99215
# 1                            0.70053                       0.92289
# 2                            0.69460                       0.92131
# 3                            0.71425                       0.93677
# 4                            0.69463                       0.93160
#
# Gas_name  station_ttc_SP95_eur_liter  station_ttc_SP98_eur_liter
# 0                            1.07377                         NaN
# 1                            1.03605                         NaN
# 2                            1.03783                         NaN
# 3                            1.05622                         NaN
# 4                            1.04988                         NaN
# correctly loaded 2009  df_station_ttc_gas_eur_liter to denormalized collection MongoDB
# YEAR:  2010  // start_date: 2010-01-01 00:00:00 end_date: 2011-01-01 00:00:00
# df_station_ttc_gas_eur_liter
#  Gas_name       Date  station_ttc_E10_eur_liter  station_ttc_E85_eur_liter  \
# 0        2010-01-01                    1.27211                    0.89467
# 1        2010-01-02                    1.24007                    0.84040
# 2        2010-01-03                    1.28735                    0.84445
# 3        2010-01-04                    1.26830                    0.84833
# 4        2010-01-05                    1.28669                    0.86800
#
# Gas_name  station_ttc_GPLC_eur_liter  station_ttc_GAZOLE_eur_liter  \
# 0                            0.69638                       1.06295
# 1                            0.65644                       1.03985
# 2                            0.70745                       1.04791
# 3                            0.68086                       1.05220
# 4                            0.69397                       1.06717
#
# Gas_name  station_ttc_SP95_eur_liter  station_ttc_SP98_eur_liter
# 0                            1.28282                         NaN
# 1                            1.26768                         NaN
# 2                            1.27071                         NaN
# 3                            1.27889                         NaN
# 4                            1.29124                         NaN
# correctly loaded 2010  df_station_ttc_gas_eur_liter to denormalized collection MongoDB
# YEAR:  2011  // start_date: 2011-01-01 00:00:00 end_date: 2012-01-01 00:00:00
# df_station_ttc_gas_eur_liter
#  Gas_name       Date  station_ttc_E10_eur_liter  station_ttc_E85_eur_liter  \
# 0        2011-01-01                    1.43855                    0.85000
# 1        2011-01-02                    1.49219                    0.85000
# 2        2011-01-03                    1.41594                    0.83884
# 3        2011-01-04                    1.44049                    0.84095
# 4        2011-01-05                    1.45294                    0.84484
#
# Gas_name  station_ttc_GPLC_eur_liter  station_ttc_GAZOLE_eur_liter  \
# 0                            0.82688                       1.26719
# 1                            0.81986                       1.24115
# 2                            0.78407                       1.24210
# 3                            0.82073                       1.25581
# 4                            0.82335                       1.25613
#
# Gas_name  station_ttc_SP95_eur_liter  station_ttc_SP98_eur_liter
# 0                            1.45732                         NaN
# 1                            1.44331                         NaN
# 2                            1.43745                         NaN
# 3                            1.44560                         NaN
# 4                            1.44767                         NaN
# correctly loaded 2011  df_station_ttc_gas_eur_liter to denormalized collection MongoDB
# YEAR:  2012  // start_date: 2012-01-01 00:00:00 end_date: 2013-01-01 00:00:00
# df_station_ttc_gas_eur_liter
#  Gas_name       Date  station_ttc_E10_eur_liter  station_ttc_E85_eur_liter  \
# 0        2012-01-01                    1.56889                    0.85000
# 1        2012-01-02                    1.49181                    0.85640
# 2        2012-01-03                    1.50753                    0.85665
# 3        2012-01-04                    1.52233                    0.87314
# 4        2012-01-05                    1.53515                    0.88252
#
# Gas_name  station_ttc_GPLC_eur_liter  station_ttc_GAZOLE_eur_liter  \
# 0                            0.86288                       1.43988
# 1                            0.82309                       1.36495
# 2                            0.83185                       1.37291
# 3                            0.83266                       1.37960
# 4                            0.84166                       1.39243
#
# Gas_name  station_ttc_SP95_eur_liter  station_ttc_SP98_eur_liter
# 0                            1.55644                         NaN
# 1                            1.51323                         NaN
# 2                            1.51695                         NaN
# 3                            1.52390                         NaN
# 4                            1.53108                         NaN
# correctly loaded 2012  df_station_ttc_gas_eur_liter to denormalized collection MongoDB
# YEAR:  2013  // start_date: 2013-01-01 00:00:00 end_date: 2014-01-01 00:00:00
# df_station_ttc_gas_eur_liter
#  Gas_name       Date  station_ttc_E10_eur_liter  station_ttc_E85_eur_liter  \
# 0        2013-01-01                    1.46829                    0.94929
# 1        2013-01-02                    1.47276                    0.92526
# 2        2013-01-03                    1.50348                    0.93361
# 3        2013-01-04                    1.50624                    0.93130
# 4        2013-01-05                    1.52166                    0.92733
#
# Gas_name  station_ttc_GPLC_eur_liter  station_ttc_GAZOLE_eur_liter  \
# 0                            0.93813                       1.34179
# 1                            0.86400                       1.34186
# 2                            0.87958                       1.34925
# 3                            0.88060                       1.35424
# 4                            0.87512                       1.35351
#
# Gas_name  station_ttc_SP95_eur_liter  station_ttc_SP98_eur_liter
# 0                            1.58390                         NaN
# 1                            1.51233                         NaN
# 2                            1.51556                         NaN
# 3                            1.52499                         NaN
# 4                            1.52556                         NaN
# correctly loaded 2013  df_station_ttc_gas_eur_liter to denormalized collection MongoDB
# YEAR:  2014  // start_date: 2014-01-01 00:00:00 end_date: 2015-01-01 00:00:00
# df_station_ttc_gas_eur_liter
#  Gas_name       Date  station_ttc_E10_eur_liter  station_ttc_E85_eur_liter  \
# 0        2014-01-01                    1.52042                    0.94583
# 1        2014-01-02                    1.47227                    0.90673
# 2        2014-01-03                    1.47224                    0.92769
# 3        2014-01-04                    1.48050                    0.88600
# 4        2014-01-05                    1.50357                    0.95000
#
# Gas_name  station_ttc_GPLC_eur_liter  station_ttc_GAZOLE_eur_liter  \
# 0                            0.88895                       1.38436
# 1                            0.83356                       1.32376
# 2                            0.83940                       1.32477
# 3                            0.85404                       1.32549
# 4                            0.90620                       1.32442
#
# Gas_name  station_ttc_SP95_eur_liter  station_ttc_SP98_eur_liter
# 0                            1.54743                     1.55249
# 1                            1.50898                     1.54239
# 2                            1.51002                     1.54392
# 3                            1.50572                     1.54341
# 4                            1.50799                     1.54587
# correctly loaded 2014  df_station_ttc_gas_eur_liter to denormalized collection MongoDB
# YEAR:  2015  // start_date: 2015-01-01 00:00:00 end_date: 2016-01-01 00:00:00
# df_station_ttc_gas_eur_liter
#  Gas_name       Date  station_ttc_E10_eur_liter  station_ttc_E85_eur_liter  \
# 0        2015-01-01                    1.36229                    0.94394
# 1        2015-01-02                    1.26752                    0.89315
# 2        2015-01-03                    1.28381                    0.86694
# 3        2015-01-04                    1.28918                    0.94410
# 4        2015-01-05                    1.27091                    0.89919
#
# Gas_name  station_ttc_GPLC_eur_liter  station_ttc_GAZOLE_eur_liter  \
# 0                            0.92184                       1.20988
# 1                            0.79669                       1.12315
# 2                            0.81314                       1.12272
# 3                            0.87938                       1.13079
# 4                            0.79622                       1.12548
#
# Gas_name  station_ttc_SP95_eur_liter  station_ttc_SP98_eur_liter
# 0                            1.36034                     1.40672
# 1                            1.28761                     1.33447
# 2                            1.28723                     1.33085
# 3                            1.29399                     1.34595
# 4                            1.28719                     1.33356
# correctly loaded 2015  df_station_ttc_gas_eur_liter to denormalized collection MongoDB
# YEAR:  2016  // start_date: 2016-01-01 00:00:00 end_date: 2017-01-01 00:00:00
# df_station_ttc_gas_eur_liter
#  Gas_name       Date  station_ttc_E10_eur_liter  station_ttc_E85_eur_liter  \
# 0        2016-01-01                    1.29030                    0.71453
# 1        2016-01-02                    1.23477                    0.71047
# 2        2016-01-03                    1.25684                    0.70943
# 3        2016-01-04                    1.24156                    0.71720
# 4        2016-01-05                    1.24829                    0.71444
#
# Gas_name  station_ttc_GPLC_eur_liter  station_ttc_GAZOLE_eur_liter  \
# 0                            0.74580                       1.09262
# 1                            0.72849                       1.02545
# 2                            0.74048                       1.05359
# 3                            0.72928                       1.03138
# 4                            0.73290                       1.03509
#
# Gas_name  station_ttc_SP95_eur_liter  station_ttc_SP98_eur_liter
# 0                            1
#
# Gas_name  station_ttc_SP95_eur_liter  station_ttc_SP98_eur_liter
# 0                            1.40044                     1.49395
# 1                            1.36858                     1.42101
# 2                            1.36626                     1.45464
# 3                            1.37478                     1.42902
# 4                            1.38040                     1.44192
# correctly loaded 2021  df_station_ttc_gas_eur_liter to denormalized collection MongoDB
# YEAR:  2022  // start_date: 2022-01-01 00:00:00 end_date: 2023-01-01 00:00:00
# df_station_ttc_gas_eur_liter
#  Gas_name       Date  station_ttc_E10_eur_liter  station_ttc_E85_eur_liter  \
# 0        2022-01-01                    1.66666                    0.73742
# 1        2022-01-02                    1.66048                    0.73834
# 2        2022-01-03                    1.63338                    0.73136
# 3        2022-01-04                    1.64766                    0.73666
# 4        2022-01-05                    1.64934                    0.73861
#
# Gas_name  station_ttc_GPLC_eur_liter  station_ttc_GAZOLE_eur_liter  \
# 0                            0.90897                       1.59720
# 1                            0.90936                       1.58789
# 2                            0.89528                       1.56363
# 3                            0.90954                       1.57393
# 4                            0.90140                       1.57547
#
# Gas_name  station_ttc_SP95_eur_liter  station_ttc_SP98_eur_liter
# 0                            1.66497                     1.76724
# 1                            1.64761                     1.76322
# 2                            1.66288                     1.71943
# 3                            1.66935                     1.73523
# 4                            1.67419                     1.73828
# correctly loaded 2022  df_station_ttc_gas_eur_liter to denormalized collection MongoDB
# YEAR:  2023  // start_date: 2023-01-01 00:00:00 end_date: 2024-01-01 00:00:00
# df_station_ttc_gas_eur_liter
#  Gas_name       Date  station_ttc_E10_eur_liter  station_ttc_E85_eur_liter  \
# 0        2023-01-01                    1.81163                    1.11720
# 1        2023-01-02                    1.79120                    1.05788
# 2        2023-01-03                    1.82532                    1.10812
# 3        2023-01-04                    1.83633                    1.11374
# 4        2023-01-05                    1.84161                    1.12419
#
# Gas_name  station_ttc_GPLC_eur_liter  station_ttc_GAZOLE_eur_liter  \
# 0                            0.99690                       1.91737
# 1                            0.97955                       1.89080
# 2                            0.98791                       1.90824
# 3                            0.99044                       1.91533
# 4                            0.98646                       1.91518
#
# Gas_name  station_ttc_SP95_eur_liter  station_ttc_SP98_eur_liter
# 0                            1.82890                     1.91196
# 1                            1.82390                     1.87265
# 2                            1.84849                     1.91223
# 3                            1.85488                     1.92080
# 4                            1.86191                     1.92452
# correctly loaded 2023  df_station_ttc_gas_eur_liter to denormalized collection MongoDB
# YEAR:  2024  // start_date: 2024-01-01 00:00:00 end_date: 2025-01-01 00:00:00
# df_station_ttc_gas_eur_liter
#  Gas_name       Date  station_ttc_E10_eur_liter  station_ttc_E85_eur_liter  \
# 0        2024-01-01                    1.79007                    0.95176
# 1        2024-01-02                    1.76445                    0.94963
# 2        2024-01-03                    1.76841                    0.93641
# 3        2024-01-04                    1.76177                    0.93512
# 4        2024-01-05                    1.76154                    0.92787
#
# Gas_name  station_ttc_GPLC_eur_liter  station_ttc_GAZOLE_eur_liter  \
# 0                            1.00679                       1.75908
# 1                            0.98738                       1.73311
# 2                            0.99098                       1.73186
# 3                            0.99221                       1.72432
# 4                            0.98950                       1.71904
#
# Gas_name  station_ttc_SP95_eur_liter  station_ttc_SP98_eur_liter
# 0                            1.79499                     1.88478
# 1                            1.80560                     1.85050
# 2                            1.79498                     1.85625
# 3                            1.79588                     1.84760
# 4                            1.79270                     1.84601
# correctly loaded 2024  df_station_ttc_gas_eur_liter to denormalized collection MongoDB
# YEAR:  2025  // start_date: 2025-01-01 00:00:00 end_date: 2026-01-01 00:00:00
# df_station_ttc_gas_eur_liter
#  Gas_name       Date  station_ttc_E10_eur_liter  station_ttc_E85_eur_liter  \
# 0        2025-01-01                    1.75098                    0.79343
# 1        2025-01-02                    1.73692                    0.78582
# 2        2025-01-03                    1.74349                    0.79075
# 3        2025-01-04                    1.75123                    0.79112
# 4        2025-01-05                    1.76463                    0.79195
#
# Gas_name  station_ttc_GPLC_eur_liter  station_ttc_GAZOLE_eur_liter  \
# 0                            1.00802                       1.68511
# 1                            1.00151                       1.66950
# 2                            1.01011                       1.67498
# 3                            1.00917                       1.68353
# 4                            1.01206                       1.69999
#
# Gas_name  station_ttc_SP95_eur_liter  station_ttc_SP98_eur_liter
# 0                            1.77197                     1.86130
# 1                            1.77162                     1.84131
# 2                            1.77232                     1.84697
# 3                            1.76892                     1.85840
# 4                            1.77121                     1.87177
# correctly loaded 2025  df_station_ttc_gas_eur_liter to denormalized collection MongoDB
