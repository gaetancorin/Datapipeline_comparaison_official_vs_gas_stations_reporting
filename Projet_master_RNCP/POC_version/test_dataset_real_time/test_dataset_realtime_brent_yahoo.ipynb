# %%
# pip install yfinance

# Étape 2 : Importer les bibliothèques nécessaires
import yfinance as yf
import pandas as pd
from datetime import datetime

# Étape 3 : Récupérer les données en temps réel du Brent (Ticker Yahoo: BZ=F)
brent = yf.Ticker("BZ=F")

print(brent.history())

# # Étape 4 : Extraire les données actuelles
# brent_data = brent.history(period="1d", interval="5m")  # données de la journée en cours, minute par minute

# # Étape 5 : Afficher les dernières valeurs
# print("📈 Dernières données minute par minute :")
# display(brent_data.tail())

# # Étape 6 : Afficher le dernier prix connu
# dernier_prix = brent_data['Close'].iloc[-1]
# print(f"\n💰 Prix actuel du Brent : {dernier_prix:.2f} USD (à {brent_data.index[-1]})")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[13], line 11
#       8 # Étape 3 : Récupérer les données en temps réel du Brent (Ticker Yahoo: BZ=F)
#       9 brent = yf.Ticker("BZ=F")
# ---> 11 print(brent.history())
#
# File ~\anaconda3\envs\python311\Lib\site-packages\yfinance\utils.py:92, in log_indent_decorator.<locals>.wrapper(*args, **kwargs)
#      89 logger.debug(f'Entering {func.__name__}()')
#      91 with IndentationContext():
# ---> 92     result = func(*args, **kwargs)
#      94 logger.debug(f'Exiting {func.__name__}()')
#      95 return result
#
# File ~\anaconda3\envs\python311\Lib\site-packages\yfinance\base.py:101, in TickerBase.history(self, *args, **kwargs)
#      99 @utils.log_indent_decorator
#     100 def history(self, *args, **kwargs) -> pd.DataFrame:
# --> 101     return self._lazy_load_price_history().history(*args, **kwargs)
#
# ...
