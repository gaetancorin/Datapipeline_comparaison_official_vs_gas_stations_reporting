# %%
import pandas as pd
import warnings
import pymongo

pd.options.mode.chained_assignment = None
warnings.filterwarnings('ignore', category=RuntimeWarning)

# Setup MongoDB connection (local)
mongo_host = "localhost"
mongo_port = 27017
mongo_user = "admin"
mongo_password = "password"
auth_db = "admin"
client_mongo = pymongo.MongoClient(
    host=mongo_host,
    port=mongo_port,
    username=mongo_user,
    password=mongo_password,
    authSource=auth_db
)
db_mongo = client_mongo.get_database("datalake")

collection_mongo = db_mongo.get_collection("french_gas_station")
cursor = collection_mongo.find({}, {"_id": 0, "Gas_station_id": 1, "Date": 1, "Nom": 1, "Valeur": 1})
df_french_gas_station = pd.DataFrame(list(cursor))

df_french_gas_station['Date'] = pd.to_datetime(df_french_gas_station['Date'])
df_french_gas_station = df_french_gas_station.rename(columns={"Nom": "Fuel_name", "Valeur": "Fuel_eur_liter"})
# Combine the gas station prices when same date and same fuel name (by mean)
df_french_gas_station = df_french_gas_station.groupby(['Date', 'Fuel_name'], as_index=False)['Fuel_eur_liter'].mean()
df_french_gas_station['Fuel_eur_liter'] = df_french_gas_station['Fuel_eur_liter'].round(5)
print("df_french_gas_station")
print(df_french_gas_station.head())


collection_mongo = db_mongo.get_collection("stockmarket_brent_usd")
cursor = collection_mongo.find({}, {"_id": 0, "Date": 1, "Close": 1})
stockmarket_brent_usd = pd.DataFrame(list(cursor))

stockmarket_brent_usd['Date'] = pd.to_datetime(stockmarket_brent_usd['Date'])
stockmarket_brent_usd = stockmarket_brent_usd.rename(columns={"Close": "Brent_usd_barrel"})
print("stockmarket_brent_usd")
print(stockmarket_brent_usd.head())


collection_mongo = db_mongo.get_collection("stockmarket_eur_usd")
cursor = collection_mongo.find({}, {"_id": 0, "Date": 1, "Close": 1})
stockmarket_eur_usd = pd.DataFrame(list(cursor))

stockmarket_eur_usd['Date'] = pd.to_datetime(stockmarket_eur_usd['Date'])
stockmarket_eur_usd = stockmarket_eur_usd.rename(columns={"Close": "Eur_usd"})
print("stockmarket_eur_usd")
print(stockmarket_eur_usd.head())

# Join 1 : gas_station avec le Brent (USD)
df_joined = pd.merge(
    df_french_gas_station,
    stockmarket_brent_usd,
    on='Date',
    how='left'
)

# Join 2 : avec le taux de change EUR/USD
df_joined = pd.merge(
    df_joined,
    stockmarket_eur_usd,
    on='Date',
    how='left'
)
df_result = df_joined.copy()
print("df_result after all the joined")
print(df_result.head())

# Create column Brent_eur
df_result['Brent_eur_barrel'] = df_result['Brent_usd_barrel'] / df_result['Eur_usd']
# Barrel contains 158,987 liters
df_result['Brent_eur_liter'] = (df_result['Brent_eur_barrel'] / 158.987).round(5)
print("df_result after create brent_eur_liter")
print(df_result.iloc[589:600])

# Clean df
df_clean = df_result.drop(columns=['Brent_usd_barrel', 'Eur_usd', 'Brent_eur_barrel'])
print("df_clean len=", len(df_clean))
print(df_clean.iloc[589:600])

# Push to MongoDB
db_mongo = client_mongo.get_database("denormalization")
# Remove collection if exist
db_mongo.drop_collection("compare_french_fuel_to_stockmarket")
collection_mongo = db_mongo.get_collection("compare_french_fuel_to_stockmarket")

records = df_clean.to_dict(orient="records")
collection_mongo.insert_many(records)
print("correctly loaded denormalized datas to MongoDB")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# Cell In[7], line 25
#      24 cursor = collection_mongo.find({}, {"_id": 0, "Gas_station_id": 1, "Date": 1, "Nom": 1, "Valeur": 1})
# ---> 25 df_french_gas_station = pd.DataFrame(list(cursor))
#      27 df_french_gas_station['Date'] = pd.to_datetime(df_french_gas_station['Date'])
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:782, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     781     columns = ensure_index(columns)
# --> 782 arrays, columns, index = nested_data_to_arrays(
#     783     # error: Argument 3 to "nested_data_to_arrays" has incompatible
#     784     # type "Optional[Collection[Any]]"; expected "Optional[Index]"
#     785     data,
#     786     columns,
#     787     index,  # type: ignore[arg-type]
#     788     dtype,
#     789 )
#     790 mgr = arrays_to_mgr(
#     791     arrays,
#     792     columns,
#    (...)
#     795     typ=manager,
#     796 )
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\construction.py:498, in nested_data_to_arrays(data, columns, index, dtype)
#     496     columns = ensure_index(data[0]._fields)
# --> 498 arrays, columns = to_arrays(data, columns, dtype=dtype)
#     499 columns = ensure_index(columns)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\construction.py:840, in to_arrays(data, columns, dtype)
#     838     arr = _list_to_arrays(data)
# --> 840 content, columns = _finalize_columns_and_data(arr, columns, dtype)
#     841 return content, columns
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\construction.py:940, in _finalize_columns_and_data(content, columns, dtype)
#     939 if len(contents) and contents[0].dtype == np.object_:
# --> 940     contents = convert_object_array(contents, dtype=dtype)
#     942 return contents, columns
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\construction.py:1067, in convert_object_array(content, dtype, dtype_backend, coerce_float)
#    1065     return arr
# -> 1067 arrays = [convert(arr) for arr in content]
#    1069 return arrays
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\construction.py:1067, in <listcomp>(.0)
#    1065     return arr
# -> 1067 arrays = [convert(arr) for arr in content]
#    1069 return arrays
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\construction.py:1025, in convert_object_array.<locals>.convert(arr)
#    1024 if dtype != np.dtype("O"):
# -> 1025     arr = lib.maybe_convert_objects(
#    1026         arr,
#    1027         try_float=coerce_float,
#    1028         convert_to_nullable_dtype=dtype_backend != "numpy",
#    1029     )
#    1030     # Notes on cases that get here 2023-02-15
#    1031     # 1) we DO get here when arr is all Timestamps and dtype=None
#    1032     # 2) disabling this doesn't break the world, so this must be
#    1033     #    getting caught at a higher level
#    1034     # 3) passing convert_datetime to maybe_convert_objects get this right
#    1035     # 4) convert_timedelta?
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\lib.pyx:2445, in pandas._libs.lib.maybe_convert_objects()
#
# File ~\anaconda3\Lib\site-packages\numpy\core\numeric.py:345, in full(shape, fill_value, dtype, order, like)
#     344 a = empty(shape, dtype, order)
# --> 345 multiarray.copyto(a, fill_value, casting='unsafe')
#     346 return a
#
# File <__array_function__ internals>:200, in copyto(*args, **kwargs)
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\executing\executing.py:317, in Source.executing(cls, frame_or_tb)
#     316 try:
# --> 317     args = executing_cache[key]
#     318 except KeyError:
#
# KeyError: (<code object __init__ at 0x00000230E5CBFD10, file "C:\Users\gaeta\anaconda3\Lib\site-packages\pandas\core\frame.py", line 641>, 2409037036816, 2176)
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:2120, in InteractiveShell.showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2119     else:
# -> 2120         stb = self.InteractiveTB.structured_traceback(
#    2121             etype, value, tb, tb_offset=tb_offset
#    2122         )
#    2124 except Exception:
#
# File ~\anaconda3\Lib\site-packages\IPython\core\ultratb.py:1435, in AutoFormattedTB.structured_traceback(self, etype, evalue, etb, tb_offset, number_of_lines_of_context)
#    1434     self.tb = etb
# -> 1435 return FormattedTB.structured_traceback(
#    1436     self, etype, evalue, etb, tb_offset, number_of_lines_of_context
#    1437 )
#
# File ~\anaconda3\Lib\site-packages\IPython\core\ultratb.py:1326, in FormattedTB.structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1324 if mode in self.verbose_modes:
#    1325     # Verbose modes need a full traceback
# -> 1326     return VerboseTB.structured_traceback(
#    1327         self, etype, value, tb, tb_offset, number_of_lines_of_context
#    1328     )
#    1329 elif mode == 'Minimal':
#
# File ~\anaconda3\Lib\site-packages\IPython\core\ultratb.py:1173, in VerboseTB.structured_traceback(self, etype, evalue, etb, tb_offset, number_of_lines_of_context)
#    1172 """Return a nice text document describing the traceback."""
# -> 1173 formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#    1174                                                        tb_offset)
#    1176 colors = self.Colors  # just a shorthand + quicker name lookup
#
# File ~\anaconda3\Lib\site-packages\IPython\core\ultratb.py:1063, in VerboseTB.format_exception_as_a_whole(self, etype, evalue, etb, number_of_lines_of_context, tb_offset)
#    1061 head = self.prepare_header(str(etype), self.long_header)
#    1062 records = (
# -> 1063     self.get_records(etb, number_of_lines_of_context, tb_offset) if etb else []
#    1064 )
#    1066 frames = []
#
# File ~\anaconda3\Lib\site-packages\IPython\core\ultratb.py:1160, in VerboseTB.get_records(self, etb, number_of_lines_of_context, tb_offset)
#    1159     return FIs
# -> 1160 res = list(stack_data.FrameInfo.stack_data(etb, options=options))[tb_offset:]
#    1161 res = [FrameInfo._from_stack_data_FrameInfo(r) for r in res]
#
# File ~\anaconda3\Lib\site-packages\stack_data\core.py:565, in FrameInfo.stack_data(cls, frame_or_tb, options, collapse_repeated_frames)
#     563     return frame.f_code, lineno
# --> 565 yield from collapse_repeated(
#     566     stack,
#     567     mapper=mapper,
#     568     collapser=RepeatedFrames,
#     569     key=_frame_key,
#     570 )
#
# File ~\anaconda3\Lib\site-packages\stack_data\utils.py:84, in collapse_repeated(lst, collapser, mapper, key)
#      83 if is_highlighted:
# ---> 84     yield from map(mapper, original_group)
#      85 else:
#
# File ~\anaconda3\Lib\site-packages\stack_data\core.py:555, in FrameInfo.stack_data.<locals>.mapper(f)
#     554 def mapper(f):
# --> 555     return cls(f, options)
#
# File ~\anaconda3\Lib\site-packages\stack_data\core.py:520, in FrameInfo.__init__(self, frame_or_tb, options)
#     515 def __init__(
#     516         self,
#     517         frame_or_tb: Union[FrameType, TracebackType],
#     518         options: Optional[Options] = None,
#     519 ):
# --> 520     self.executing = Source.executing(frame_or_tb)
#     521     frame, self.lineno = frame_and_lineno(frame_or_tb)
#
# File ~\anaconda3\Lib\site-packages\executing\executing.py:369, in Source.executing(cls, frame_or_tb)
#     367     return source, node, stmts, decorator
# --> 369 args = find(source=cls.for_frame(frame), retry_cache=True)
#     370 executing_cache[key] = args
#
# File ~\anaconda3\Lib\site-packages\executing\executing.py:252, in Source.for_frame(cls, frame, use_cache)
#     249 """
#     250 Returns the `Source` object corresponding to the file the frame is executing in.
#     251 """
# --> 252 return cls.for_filename(frame.f_code.co_filename, frame.f_globals or {}, use_cache)
#
# File ~\anaconda3\Lib\site-packages\executing\executing.py:270, in Source.for_filename(cls, filename, module_globals, use_cache)
#     269 lines = tuple(linecache.getlines(filename, module_globals))
# --> 270 result = source_cache[filename] = cls._for_filename_and_lines(filename, lines)
#     271 return result
#
# File ~\anaconda3\Lib\site-packages\executing\executing.py:281, in Source._for_filename_and_lines(cls, filename, lines)
#     279     pass
# --> 281 result = source_cache[(filename, lines)] = cls(filename, lines)
#     282 return result
#
# File ~\anaconda3\Lib\site-packages\stack_data\core.py:81, in Source.__init__(self, *args, **kwargs)
#      80 if self.tree:
# ---> 81     self.asttokens()
#
# File ~\anaconda3\Lib\site-packages\executing\executing.py:413, in Source.asttokens(self)
#     412 from asttokens import ASTTokens  # must be installed separately
# --> 413 return ASTTokens(
#     414     self.text,
#     415     tree=self.tree,
#     416     filename=self.filename,
#     417 )
#
# File ~\anaconda3\Lib\site-packages\asttokens\asttokens.py:59, in ASTTokens.__init__(self, source_text, parse, tree, filename)
#      58 # Tokenize the code.
# ---> 59 self._tokens = list(self._generate_tokens(source_text))
#      61 # Extract the start positions of all tokens, so that we can quickly map positions to tokens.
#
# File ~\anaconda3\Lib\site-packages\asttokens\asttokens.py:85, in ASTTokens._generate_tokens(self, text)
#      83 # This is technically an undocumented API for Python3, but allows us to use the same API as for
#      84 # Python2. See http://stackoverflow.com/a/4952291/328565.
# ---> 85 for index, tok in enumerate(tokenize.generate_tokens(io.StringIO(text).readline)):
#      86   tok_type, tok_str, start, end, line = tok
#
# File ~\anaconda3\Lib\tokenize.py:531, in _tokenize(readline, encoding)
#     530 if pseudomatch:                                # scan for tokens
# --> 531     start, end = pseudomatch.span(1)
#     532     spos, epos, pos = (lnum, start), (lnum, end), end
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# File ~\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:2141, in InteractiveShell.showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2138         self._showtraceback(etype, value, stb)
#    2140 except KeyboardInterrupt:
# -> 2141     print('\n' + self.get_exception_only(), file=sys.stderr)
#
# File ~\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:2064, in InteractiveShell.get_exception_only(self, exc_tuple)
#    2059 """
#    2060 Return as a string (ending with a newline) the exception that
#    2061 just occurred, without any traceback.
#    2062 """
#    2063 etype, value, tb = self._get_exc_info(exc_tuple)
# -> 2064 msg = traceback.format_exception_only(etype, value)
#    2065 return ''.join(msg)
#
# File ~\anaconda3\Lib\traceback.py:159, in format_exception_only(exc, value)
#     157 if value is _sentinel:
#     158     value = exc
# --> 159 te = TracebackException(type(value), value, None, compact=True)
#     160 return list(te.format_exception_only())
#
# File ~\anaconda3\Lib\traceback.py:747, in TracebackException.__init__(self, exc_type, exc_value, exc_traceback, limit, lookup_lines, capture_locals, compact, max_group_width, max_group_depth, _seen)
#     744     need_context = True
#     745 if (e and e.__context__ is not None
#     746     and need_context and id(e.__context__) not in _seen):
# --> 747     context = TracebackException(
#     748         type(e.__context__),
#     749         e.__context__,
#     750         e.__context__.__traceback__,
#     751         limit=limit,
#     752         lookup_lines=lookup_lines,
#     753         capture_locals=capture_locals,
#     754         max_group_width=max_group_width,
#     755         max_group_depth=max_group_depth,
#     756         _seen=_seen)
#     757 else:
#     758     context = None
#
# File ~\anaconda3\Lib\traceback.py:692, in TracebackException.__init__(self, exc_type, exc_value, exc_traceback, limit, lookup_lines, capture_locals, compact, max_group_width, max_group_depth, _seen)
#     689 self.max_group_width = max_group_width
#     690 self.max_group_depth = max_group_depth
# --> 692 self.stack = StackSummary._extract_from_extended_frame_gen(
#     693     _walk_tb_with_full_positions(exc_traceback),
#     694     limit=limit, lookup_lines=lookup_lines,
#     695     capture_locals=capture_locals)
#     696 self.exc_type = exc_type
#     697 # Capture now to permit freeing resources: only complication is in the
#     698 # unofficial API _format_final_exc_line
#
# File ~\anaconda3\Lib\traceback.py:436, in StackSummary._extract_from_extended_frame_gen(klass, frame_gen, limit, lookup_lines, capture_locals)
#     434 if lookup_lines:
#     435     for f in result:
# --> 436         f.line
#     437 return result
#
# File ~\anaconda3\Lib\traceback.py:321, in FrameSummary.line(self)
#     319     if self.lineno is None:
#     320         return None
# --> 321     self._line = linecache.getline(self.filename, self.lineno)
#     322 return self._line.strip()
#
# File ~\anaconda3\Lib\linecache.py:30, in getline(filename, lineno, module_globals)
#      26 def getline(filename, lineno, module_globals=None):
#      27     """Get a line for a Python source file from the cache.
#      28     Update the cache if it doesn't contain an entry for this file already."""
# ---> 30     lines = getlines(filename, module_globals)
#      31     if 1 <= lineno <= len(lines):
#      32         return lines[lineno - 1]
#
# File ~\anaconda3\Lib\linecache.py:46, in getlines(filename, module_globals)
#      43         return cache[filename][2]
#      45 try:
# ---> 46     return updatecache(filename, module_globals)
#      47 except MemoryError:
#      48     clearcache()
#
# File ~\anaconda3\Lib\linecache.py:93, in updatecache(filename, module_globals)
#      91 fullname = filename
#      92 try:
# ---> 93     stat = os.stat(fullname)
#      94 except OSError:
#      95     basename = filename
#
# KeyboardInterrupt:
