# %%
import pandas as pd
import warnings
import pymongo
from datetime import datetime

pd.options.mode.chained_assignment = None
warnings.filterwarnings('ignore', category=RuntimeWarning)

# Setup MongoDB connection (local)
mongo_host = "localhost"
mongo_port = 27017
mongo_user = "admin"
mongo_password = "password"
auth_db = "admin"
client_mongo = pymongo.MongoClient(
    host=mongo_host,
    port=mongo_port,
    username=mongo_user,
    password=mongo_password,
    authSource=auth_db
)
db_mongo_denorm = client_mongo.get_database("denormalization")
db_mongo_denorm.drop_collection("compare_french_gas_to_stockmarket")

db_mongo_datalake = client_mongo.get_database("datalake")

# ALL YEARS
years = ['2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022', '2023', '2024', '2025']
#years = ['2007', '2008', '2009', '2010', '2011', '2012']
# ONE YEAR
# years = ['2007']


for year in years:
    year = int(year)
    print("YEAR: ", year, " // start_date:", datetime(year, 1, 1), "end_date:", datetime(year+1, 1, 1))
    
    # --- collection french_gas_station ----
    collection_mongo = db_mongo_datalake.get_collection("french_gas_station_price_logs_eur")
    cursor = collection_mongo.find(
        {
            "Date": {"$gte": datetime(year, 1, 1), "$lt": datetime(year+1, 1, 1)}
        },
        {
            "_id": 0, "Id_station_essence": 1, "Date": 1, "Nom": 1, "Valeur": 1
        }
    )
    df_french_gas_station = pd.DataFrame(list(cursor))

    df_french_gas_station['Date'] = pd.to_datetime(df_french_gas_station['Date'])
    df_french_gas_station = df_french_gas_station.rename(columns={
        "Id_station_essence": "Gas_station_id", "Nom": "Gas_name", "Valeur": "Gas_eur_liter"
    })
    # Combine the gas station prices when same date and same gas name (by mean)
    df_french_gas_station = df_french_gas_station.groupby(['Date', 'Gas_name'], as_index=False)['Gas_eur_liter'].mean().round(5)
    
    # Create col for each gas_name (pivot rotate df)
    df_french_gas_station = df_french_gas_station.pivot(index='Date', columns='Gas_name', values='Gas_eur_liter')
    df_french_gas_station = df_french_gas_station.rename(columns=lambda x: f"Gas_{x.upper()}_eur_liter").reset_index()
#     print("df_french_gas_station\n", df_french_gas_station)
    
    # always have all existing columns
    all_fuel_name_existing = [
        "Gas_E10_eur_liter",
        "Gas_E85_eur_liter",
        "Gas_GPLC_eur_liter",
        "Gas_GAZOLE_eur_liter",
        "Gas_SP95_eur_liter",
        "Gas_SP98_eur_liter"
    ]
    for col in all_fuel_name_existing:
        if col not in df_french_gas_station.columns:
            df_french_gas_station[col] = float('nan')
    
    print("df_french_gas_station")
    print(df_french_gas_station.head())


    # --- collection stockmarket_brent_usd ----
    collection_mongo = db_mongo_datalake.get_collection("stockmarket_brent_usd")
    cursor = collection_mongo.find(
        {
            "Date": {"$gte": datetime(year, 1, 1), "$lt": datetime(year+1, 1, 1)}
        },
        {
            "_id": 0, "Date": 1, "Close": 1
        }
    )
    stockmarket_brent_usd = pd.DataFrame(list(cursor))

    stockmarket_brent_usd['Date'] = pd.to_datetime(stockmarket_brent_usd['Date'])
    stockmarket_brent_usd = stockmarket_brent_usd.rename(columns={"Close": "Brent_usd_barrel"})
    print("stockmarket_brent_usd")
    print(stockmarket_brent_usd.head())


    # --- collection stockmarket_eur_usd ----
    collection_mongo = db_mongo_datalake.get_collection("stockmarket_eur_usd")
    cursor = collection_mongo.find(
        {
            "Date": {"$gte": datetime(year, 1, 1), "$lt": datetime(year+1, 1, 1)} 
        },
        {
            "_id": 0, "Date": 1, "Close": 1
        }
    )
    stockmarket_eur_usd = pd.DataFrame(list(cursor))

    stockmarket_eur_usd['Date'] = pd.to_datetime(stockmarket_eur_usd['Date'])
    stockmarket_eur_usd = stockmarket_eur_usd.rename(columns={"Close": "Eur_usd"})
    print("stockmarket_eur_usd")
    print(stockmarket_eur_usd.head())

    # --- join the 3 collections ----
    df_joined = pd.merge(
        df_french_gas_station,
        stockmarket_brent_usd,
        on='Date',
        how='left'
    )

    # Join 2 : avec le taux de change EUR/USD
    df_joined = pd.merge(
        df_joined,
        stockmarket_eur_usd,
        on='Date',
        how='left'
    )
    df_result = df_joined.copy()
    print("df_result after all the joined")
    print(df_result.head())

    # ---- Create column Brent_eur_liter -----
    df_result['Brent_eur_barrel'] = df_result['Brent_usd_barrel'] / df_result['Eur_usd']
    # Barrel contains 158,987 liters
    df_result['BRENT_eur_liter'] = (df_result['Brent_eur_barrel'] / 158.987).round(5)
    print("df_result after create BRENT_eur_liter")
    print(df_result.head())

    df_clean = df_result.drop(columns=['Brent_usd_barrel', 'Eur_usd', 'Brent_eur_barrel'])
    print("df_clean len=", len(df_clean))
    print(df_clean.head(10))

    # ----- Push to MongoDB -----
    collection_mongo = db_mongo_denorm.get_collection("compare_french_gas_to_stockmarket")
    collection_mongo.create_index([("Date", pymongo.ASCENDING)])

    records = df_clean.to_dict(orient="records")
    collection_mongo.insert_many(records)
    print("correctly loaded", year,"denormalized datas to MongoDB")
# Out:
# YEAR:  2007  // start_date: 2007-01-01 00:00:00 end_date: 2008-01-01 00:00:00
# df_french_gas_station
# Gas_name       Date  Gas_E85_eur_liter  Gas_GPLC_eur_liter  \
# 0        2007-01-01                NaN                 NaN
# 1        2007-01-02                NaN                 NaN
# 2        2007-01-03                NaN                 NaN
# 3        2007-01-04                NaN                 NaN
# 4        2007-01-05                NaN                 NaN
#
# Gas_name  Gas_GAZOLE_eur_liter  Gas_SP95_eur_liter  Gas_E10_eur_liter  \
# 0                      1.10647             1.24179                NaN
# 1                      1.00571             1.17889                NaN
# 2                      1.00645             1.18080                NaN
# 3                      1.02514             1.18936                NaN
# 4                      1.00072             1.17936                NaN
#
# Gas_name  Gas_SP98_eur_liter
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                        NaN
# stockmarket_brent_usd
#         Date  Brent_usd_barrel
# 0 2007-07-30             75.74
# 1 2007-07-31             77.05
# 2 2007-08-01             75.35
# 3 2007-08-02             75.76
# 4 2007-08-03             74.75
# stockmarket_eur_usd
#         Date  Eur_usd
# 0 2007-01-01   1.3219
# 1 2007-01-02   1.3276
# 2 2007-01-03   1.3171
# 3 2007-01-04   1.3093
# 4 2007-01-05   1.2985
# df_result after all the joined
#         Date  Gas_E85_eur_liter  Gas_GPLC_eur_liter  Gas_GAZOLE_eur_liter  \
# 0 2007-01-01                NaN                 NaN               1.10647
# 1 2007-01-02                NaN                 NaN               1.00571
# 2 2007-01-03                NaN                 NaN               1.00645
# 3 2007-01-04                NaN                 NaN               1.02514
# 4 2007-01-05                NaN                 NaN               1.00072
#
#    Gas_SP95_eur_liter  Gas_E10_eur_liter  Gas_SP98_eur_liter  \
# 0             1.24179                NaN                 NaN
# 1             1.17889                NaN                 NaN
# 2             1.18080                NaN                 NaN
# 3             1.18936                NaN                 NaN
# 4             1.17936                NaN                 NaN
#
#    Brent_usd_barrel  Eur_usd
# 0               NaN   1.3219
# 1               NaN   1.3276
# 2               NaN   1.3171
# 3               NaN   1.3093
# 4               NaN   1.2985
# df_result after create BRENT_eur_liter
#         Date  Gas_E85_eur_liter  Gas_GPLC_eur_liter  Gas_GAZOLE_eur_liter  \
# 0 2007-01-01                NaN                 NaN               1.10647
# 1 2007-01-02                NaN                 NaN               1.00571
# 2 2007-01-03                NaN                 NaN               1.00645
# 3 2007-01-04                NaN                 NaN               1.02514
# 4 2007-01-05                NaN                 NaN               1.00072
#
#    Gas_SP95_eur_liter  Gas_E10_eur_liter  Gas_SP98_eur_liter  \
# 0             1.24179                NaN                 NaN
# 1             1.17889                NaN                 NaN
# 2             1.18080                NaN                 NaN
# 3             1.18936                NaN                 NaN
# 4             1.17936                NaN                 NaN
#
#    Brent_usd_barrel  Eur_usd  Brent_eur_barrel  BRENT_eur_liter
# 0               NaN   1.3219               NaN              NaN
# 1               NaN   1.3276               NaN              NaN
# 2               NaN   1.3171               NaN              NaN
# 3               NaN   1.3093               NaN              NaN
# 4               NaN   1.2985               NaN              NaN
# df_clean len= 365
#         Date  Gas_E85_eur_liter  Gas_GPLC_eur_liter  Gas_GAZOLE_eur_liter  \
# 0 2007-01-01                NaN                 NaN               1.10647
# 1 2007-01-02                NaN                 NaN               1.00571
# 2 2007-01-03                NaN                 NaN               1.00645
# 3 2007-01-04                NaN                 NaN               1.02514
# 4 2007-01-05                NaN                 NaN               1.00072
# 5 2007-01-06                NaN                 NaN               0.99230
# 6 2007-01-07                NaN                 NaN               1.03265
# 7 2007-01-08                NaN                 NaN               0.99170
# 8 2007-01-09                NaN                 NaN               1.00203
# 9 2007-01-10                NaN                 NaN               1.00007
#
#    Gas_SP95_eur_liter  Gas_E10_eur_liter  Gas_SP98_eur_liter  BRENT_eur_liter
# 0             1.24179                NaN                 NaN              NaN
# 1             1.17889                NaN                 NaN              NaN
# 2             1.18080                NaN                 NaN              NaN
# 3             1.18936                NaN                 NaN              NaN
# 4             1.17936                NaN                 NaN              NaN
# 5             1.17837                NaN                 NaN              NaN
# 6             1.19636                NaN                 NaN              NaN
# 7             1.17601                NaN                 NaN              NaN
# 8             1.17930                NaN                 NaN              NaN
# 9             1.17202                NaN                 NaN              NaN
# correctly loaded 2007 denormalized datas to MongoDB
# YEAR:  2008  // start_date: 2008-01-01 00:00:00 end_date: 2009-01-01 00:00:00
# df_french_gas_station
# Gas_name       Date  Gas_E85_eur_liter  Gas_GPLC_eur_liter  \
# 0        2008-01-01            0.82000             0.76720
# 1        2008-01-02            0.80577             0.72946
# 2        2008-01-03            0.81065             0.74724
# 3        2008-01-04            0.81141             0.73195
# 4        2008-01-05            0.80834             0.73563
#
# Gas_name  Gas_GAZOLE_eur_liter  Gas_SP95_eur_liter  Gas_E10_eur_liter  \
# 0                      1.25893             1.38413                NaN
# 1                      1.19713             1.35771                NaN
# 2                      1.20087             1.36717                NaN
# 3                      1.20449             1.36928                NaN
# 4                      1.20261             1.36844                NaN
#
# Gas_name  Gas_SP98_eur_liter
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                        NaN
# stockmarket_brent_usd
#         Date  Brent_usd_barrel
# 0 2008-01-02             97.84
# 1 2008-01-03             97.60
# 2 2008-01-04             96.79
# 3 2008-01-07             94.39
# 4 2008-01-08             95.54
# stockmarket_eur_usd
#         Date  Eur_usd
# 0 2008-01-01   1.4620
# 1 2008-01-02   1.4717
# 2 2008-01-03   1.4745
# 3 2008-01-04   1.4755
# 4 2008-01-07   1.4683
# df_result after all the joined
#         Date  Gas_E85_eur_liter  Gas_GPLC_eur_liter  Gas_GAZOLE_eur_liter  \
# 0 2008-01-01            0.82000             0.76720               1.25893
# 1 2008-01-02            0.80577             0.72946               1.19713
# 2 2008-01-03            0.81065             0.74724               1.20087
# 3 2008-01-04            0.81141             0.73195               1.20449
# 4 2008-01-05            0.80834             0.73563               1.20261
#
#    Gas_SP95_eur_liter  Gas_E10_eur_liter  Gas_SP98_eur_liter  \
# 0             1.38413                NaN                 NaN
# 1             1.35771                NaN                 NaN
# 2             1.36717                NaN                 NaN
# 3             1.36928                NaN                 NaN
# 4             1.36844                NaN                 NaN
#
#    Brent_usd_barrel  Eur_usd
# 0               NaN   1.4620
# 1             97.84   1.4717
# 2             97.60   1.4745
# 3             96.79   1.4755
# 4               NaN      NaN
# df_result after create BRENT_eur_liter
#         Date  Gas_E85_eur_liter  Gas_GPLC_eur_liter  Gas_GAZOLE_eur_liter  \
# 0 2008-01-01            0.82000             0.76720               1.25893
# 1 2008-01-02            0.80577             0.72946               1.19713
# 2 2008-01-03            0.81065             0.74724               1.20087
# 3 2008-01-04            0.81141             0.73195               1.20449
# 4 2008-01-05            0.80834             0.73563               1.20261
#
#    Gas_SP95_eur_liter  Gas_E10_eur_liter  Gas_SP98_eur_liter  \
# 0             1.38413                NaN                 NaN
# 1             1.35771                NaN                 NaN
# 2             1.36717                NaN                 NaN
# 3             1.36928                NaN                 NaN
# 4             1.36844                NaN                 NaN
#
#    Brent_usd_barrel  Eur_usd  Brent_eur_barrel  BRENT_eur_liter
# 0               NaN   1.4620               NaN              NaN
# 1             97.84   1.4717         66.480940          0.41815
# 2             97.60   1.4745         66.191929          0.41634
# 3             96.79   1.4755         65.598102          0.41260
# 4               NaN      NaN               NaN              NaN
# df_clean len= 366
#         Date  Gas_E85_eur_liter  Gas_GPLC_eur_liter  Gas_GAZOLE_eur_liter  \
# 0 2008-01-01            0.82000             0.76720               1.25893
# 1 2008-01-02            0.80577             0.72946               1.19713
# 2 2008-01-03            0.81065             0.74724               1.20087
# 3 2008-01-04            0.81141             0.73195               1.20449
# 4 2008-01-05            0.80834             0.73563               1.20261
# 5 2008-01-06            0.82000             0.77200               1.22541
# 6 2008-01-07            0.80933             0.71768               1.20381
# 7 2008-01-08            0.80997             0.71487               1.20086
# 8 2008-01-09            0.80905             0.73592               1.19988
# 9 2008-01-10            0.80844             0.71767               1.19070
#
#    Gas_SP95_eur_liter  Gas_E10_eur_liter  Gas_SP98_eur_liter  BRENT_eur_liter
# 0             1.38413                NaN                 NaN              NaN
# 1             1.35771                NaN                 NaN          0.41815
# 2             1.36717                NaN                 NaN          0.41634
# 3             1.36928                NaN                 NaN          0.41260
# 4             1.36844                NaN                 NaN              NaN
# 5             1.38625                NaN                 NaN              NaN
# 6             1.37311                NaN                 NaN          0.40434
# 7             1.36943                NaN                 NaN          0.38593
# 8             1.36544                NaN                 NaN          0.40478
# 9             1.36352                NaN                 NaN          0.39190
# correctly loaded 2008 denormalized datas to MongoDB
# YEAR:  2009  // start_date: 2009-01-01 00:00:00 end_date: 2010-01-01 00:00:00
# df_french_gas_station
# Gas_name       Date  Gas_E10_eur_liter  Gas_E85_eur_liter  Gas_GPLC_eur_liter  \
# 0        2009-01-01                NaN                NaN             0.69737
# 1        2009-01-02                NaN            0.83753             0.70053
# 2        2009-01-03                NaN            0.83622             0.69460
# 3        2009-01-04                NaN            0.84833             0.71425
# 4        2009-01-05                NaN            0.83705             0.69463
#
# Gas_name  Gas_GAZOLE_eur_liter  Gas_SP95_eur_liter  Gas_SP98_eur_liter
# 0                      0.99215             1.07377                 NaN
# 1                      0.92289             1.03605                 NaN
# 2                      0.92131             1.03783                 NaN
# 3                      0.93677             1.05622                 NaN
# 4                      0.93160             1.04988                 NaN
# stockmarket_brent_usd
#         Date  Brent_usd_barrel
# 0 2009-01-02             46.91
# 1 2009-01-05             49.62
# 2 2009-01-06             50.53
# 3 2009-01-07             45.86
# 4 2009-01-08             44.67
# stockmarket_eur_usd
#         Date  Eur_usd
# 0 2009-01-01   1.3999
# 1 2009-01-02   1.3923
# 2 2009-01-05   1.3646
# 3 2009-01-06   1.3510
# 4 2009-01-07   1.3611
# df_result after all the joined
#         Date  Gas_E10_eur_liter  Gas_E85_eur_liter  Gas_GPLC_eur_liter  \
# 0 2009-01-01                NaN                NaN             0.69737
# 1 2009-01-02                NaN            0.83753             0.70053
# 2 2009-01-03                NaN            0.83622             0.69460
# 3 2009-01-04                NaN            0.84833             0.71425
# 4 2009-01-05                NaN            0.83705             0.69463
#
#    Gas_GAZOLE_eur_liter  Gas_SP95_eur_liter  Gas_SP98_eur_liter  \
# 0               0.99215             1.07377                 NaN
# 1               0.92289             1.03605                 NaN
# 2               0.92131             1.03783                 NaN
# 3               0.93677             1.05622                 NaN
# 4               0.93160             1.04988                 NaN
#
#    Brent_usd_barrel  Eur_usd
# 0               NaN   1.3999
# 1             46.91   1.3923
# 2               NaN      NaN
# 3               NaN      NaN
# 4             49.62   1.3646
# df_result after create BRENT_eur_liter
#         Date  Gas_E10_eur_liter  Gas_E85_eur_liter  Gas_GPLC_eur_liter  \
# 0 2009-01-01                NaN                NaN             0.69737
# 1 2009-01-02                NaN            0.83753             0.70053
# 2 2009-01-03                NaN            0.83622             0.69460
# 3 2009-01-04                NaN            0.84833             0.71425
# 4 2009-01-05                NaN            0.83705             0.69463
#
#    Gas_GAZOLE_eur_liter  Gas_SP95_eur_liter  Gas_SP98_eur_liter  \
# 0               0.99215             1.07377                 NaN
# 1               0.92289             1.03605                 NaN
# 2               0.92131             1.03783                 NaN
# 3               0.93677             1.05622                 NaN
# 4               0.93160             1.04988                 NaN
#
#    Brent_usd_barrel  Eur_usd  Brent_eur_barrel  BRENT_eur_liter
# 0               NaN   1.3999               NaN              NaN
# 1             46.91   1.3923         33.692451          0.21192
# 2               NaN      NaN               NaN              NaN
# 3               NaN      NaN               NaN              NaN
# 4             49.62   1.3646         36.362304          0.22871
# df_clean len= 365
#         Date  Gas_E10_eur_liter  Gas_E85_eur_liter  Gas_GPLC_eur_liter  \
# 0 2009-01-01                NaN                NaN             0.69737
# 1 2009-01-02                NaN            0.83753             0.70053
# 2 2009-01-03                NaN            0.83622             0.69460
# 3 2009-01-04                NaN            0.84833             0.71425
# 4 2009-01-05                NaN            0.83705             0.69463
# 5 2009-01-06                NaN            0.83572             0.69385
# 6 2009-01-07                NaN            0.83493             0.70217
# 7 2009-01-08                NaN            0.83780             0.69375
# 8 2009-01-09                NaN            0.83364             0.69296
# 9 2009-01-10                NaN            0.83561             0.69517
#
#    Gas_GAZOLE_eur_liter  Gas_SP95_eur_liter  Gas_SP98_eur_liter  \
# 0               0.99215             1.07377                 NaN
# 1               0.92289             1.03605                 NaN
# 2               0.92131             1.03783                 NaN
# 3               0.93677             1.05622                 NaN
# 4               0.93160             1.04988                 NaN
# 5               0.94753             1.06904                 NaN
# 6               0.98504             1.09958                 NaN
# 7               0.99829             1.11129                 NaN
# 8               0.99915             1.11087                 NaN
# 9               0.98443             1.10462                 NaN
#
#    BRENT_eur_liter
# 0              NaN
# 1          0.21192
# 2              NaN
# 3              NaN
# 4          0.22871
# 5          0.23525
# 6          0.21193
# 7          0.20510
# 8          0.20765
# 9              NaN
# correctly loaded 2009 denormalized datas to MongoDB
# YEAR:  2010  // start_date: 2010-01-01 00:00:00 end_date: 2011-01-01 00:00:00
# df_french_gas_station
# Gas_name       Date  Gas_E10_eur_liter  Gas_E85_eur_liter  Gas_GPLC_eur_liter  \
# 0        2010-01-01            1.27211            0.89467             0.69638
# 1        2010-01-02            1.24007            0.84040             0.65644
# 2        2010-01-03            1.28735            0.84445             0.70745
# 3        2010-01-04            1.26830            0.84833             0.68086
# 4        2010-01-05            1.28669            0.86800             0.69397
#
# Gas_name  Gas_GAZOLE_eur_liter  Gas_SP95_eur_liter  Gas_SP98_eur_liter
# 0                      1.06295             1.28282                 NaN
# 1                      1.03985             1.26768                 NaN
# 2                      1.04791             1.27071                 NaN
# 3                      1.05220             1.27889                 NaN
# 4                      1.06717             1.29124                 NaN
# stockmarket_brent_usd
#         Date  Brent_usd_barrel
# 0 2010-01-04             80.12
# 1 2010-01-05             80.59
# 2 2010-01-06             81.89
# 3 2010-01-07             81.51
# 4 2010-01-08             81.37
# stockmarket_eur_usd
#         Date  Eur_usd
# 0 2010-01-01   1.4390
# 1 2010-01-04   1.4424
# 2 2010-01-05   1.4366
# 3 2010-01-06   1.4404
# 4 2010-01-07   1.4318
# df_result after all the joined
#         Date  Gas_E10_eur_liter  Gas_E85_eur_liter  Gas_GPLC_eur_liter  \
# 0 2010-01-01            1.27211            0.89467             0.69638
# 1 2010-01-02            1.24007            0.84040             0.65644
# 2 2010-01-03            1.28735            0.84445             0.70745
# 3 2010-01-04            1.26830            0.84833             0.68086
# 4 2010-01-05            1.28669            0.86800             0.69397
#
#    Gas_GAZOLE_eur_liter  Gas_SP95_eur_liter  Gas_SP98_eur_liter  \
# 0               1.06295             1.28282                 NaN
# 1               1.03985             1.26768                 NaN
# 2               1.04791             1.27071                 NaN
# 3               1.05220             1.27889                 NaN
# 4               1.06717             1.29124                 NaN
#
#    Brent_usd_barrel  Eur_usd
# 0               NaN   1.4390
# 1               NaN      NaN
# 2               NaN      NaN
# 3             80.12   1.4424
# 4             80.59   1.4366
# df_result after create BRENT_eur_liter
#         Date  Gas_E10_eur_liter  Gas_E85_eur_liter  Gas_GPLC_eur_liter  \
# 0 2010-01-01            1.27211            0.89467             0.69638
# 1 2010-01-02            1.24007            0.84040             0.65644
# 2 2010-01-03            1.28735            0.84445             0.70745
# 3 2010-01-04            1.26830            0.84833             0.68086
# 4 2010-01-05            1.28669            0.86800             0.69397
#
#    Gas_GAZOLE_eur_liter  Gas_SP95_eur_liter  Gas_SP98_eur_liter  \
# 0               1.06295             1.28282                 NaN
# 1               1.03985             1.26768                 NaN
# 2               1.04791             1.27071                 NaN
# 3               1.05220             1.27889                 NaN
# 4               1.06717             1.29124                 NaN
#
#    Brent_usd_barrel  Eur_usd  Brent_eur_barrel  BRENT_eur_liter
# 0               NaN   1.4390               NaN              NaN
# 1               NaN      NaN               NaN              NaN
# 2               NaN      NaN               NaN              NaN
# 3             80.12   1.4424         55.546312          0.34938
# 4             80.59   1.4366         56.097731          0.35284
# df_clean len= 365
#         Date  Gas_E10_eur_liter  Gas_E85_eur_liter  Gas_GPLC_eur_liter  \
# 0 2010-01-01            1.27211            0.89467             0.69638
# 1 2010-01-02            1.24007            0.84040             0.65644
# 2 2010-01-03            1.28735            0.84445             0.70745
# 3 2010-01-04            1.26830            0.84833             0.68086
# 4 2010-01-05            1.28669            0.86800             0.69397
# 5 2010-01-06            1.29717            0.86665             0.69274
# 6 2010-01-07            1.28865            0.86238             0.68872
# 7 2010-01-08            1.29508            0.86181             0.69519
# 8 2010-01-09            1.31723            0.83277             0.68958
# 9 2010-01-10            1.30378            0.84667             0.69313
#
#    Gas_GAZOLE_eur_liter  Gas_SP95_eur_liter  Gas_SP98_eur_liter  \
# 0               1.06295             1.28282                 NaN
# 1               1.03985             1.26768                 NaN
# 2               1.04791             1.27071                 NaN
# 3               1.05220             1.27889                 NaN
# 4               1.06717             1.29124                 NaN
# 5               1.07670             1.29571                 NaN
# 6               1.07614             1.30127                 NaN
# 7               1.07482             1.30057                 NaN
# 8               1.07717             1.30093                 NaN
# 9               1.07486             1.30310                 NaN
#
#    BRENT_eur_liter
# 0              NaN
# 1              NaN
# 2              NaN
# 3          0.34938
# 4          0.35284
# 5          0.35759
# 6          0.35807
# 7          0.35515
# 8              NaN
# 9              NaN
# correctly loaded 2010 denormalized datas to MongoDB
# YEAR:  2011  // start_date: 2011-01-01 00:00:00 end_date: 2012-01-01 00:00:00
# df_french_gas_station
# Gas_name       Date  Gas_E10_eur_liter  Gas_E85_eur_liter  Gas_GPLC_eur_liter  \
# 0        2011-01-01            1.43855            0.85000             0.82688
# 1        2011-01-02            1.49219            0.85000             0.81986
# 2        2011-01-03            1.41594            0.83884             0.78407
# 3        2011-01-04            1.44049            0.84095             0.82073
# 4        2011-01-05            1.45294            0.84484             0.82335
#
# Gas_name  Gas_GAZOLE_eur_liter  Gas_SP95_eur_liter  Gas_SP98_eur_liter
# 0                      1.26719             1.45732                 NaN
# 1                      1.24115             1.44331                 NaN
# 2                      1.24210             1.43745                 NaN
# 3                      1.25581             1.44560                 NaN
# 4                      1.25613             1.44767                 NaN
# stockmarket_brent_usd
#         Date  Brent_usd_barrel
# 0 2011-01-03             94.84
# 1 2011-01-04             93.53
# 2 2011-01-05             95.50
# 3 2011-01-06             94.52
# 4 2011-01-07             93.33
# stockmarket_eur_usd
#         Date  Eur_usd
# 0 2011-01-03   1.3358
# 1 2011-01-04   1.3357
# 2 2011-01-05   1.3321
# 3 2011-01-06   1.3157
# 4 2011-01-07   1.2980
# df_result after all the joined
#         Date  Gas_E10_eur_liter  Gas_E85_eur_liter  Gas_GPLC_eur_liter  \
# 0 2011-01-01            1.43855            0.85000             0.82688
# 1 2011-01-02            1.49219            0.85000             0.81986
# 2 2011-01-03            1.41594            0.83884             0.78407
# 3 2011-01-04            1.44049            0.84095             0.82073
# 4 2011-01-05            1.45294            0.84484             0.82335
#
#    Gas_GAZOLE_eur_liter  Gas_SP95_eur_liter  Gas_SP98_eur_liter  \
# 0               1.26719             1.45732                 NaN
# 1               1.24115             1.44331                 NaN
# 2               1.24210             1.43745                 NaN
# 3               1.25581             1.44560                 NaN
# 4               1.25613             1.44767                 NaN
#
#    Brent_usd_barrel  Eur_usd
# 0               NaN      NaN
# 1               NaN      NaN
# 2             94.84   1.3358
# 3             93.53   1.3357
# 4             95.50   1.3321
# df_result after create BRENT_eur_liter
#         Date  Gas_E10_eur_liter  Gas_E85_eur_liter  Gas_GPLC_eur_liter  \
# 0 2011-01-01            1.43855            0.85000             0.82688
# 1 2011-01-02            1.49219            0.85000             0.81986
# 2 2011-01-03            1.41594            0.83884             0.78407
# 3 2011-01-04            1.44049            0.84095             0.82073
# 4 2011-01-05            1.45294            0.84484             0.82335
#
#    Gas_GAZOLE_eur_liter  Gas_SP95_eur_liter  Gas_SP98_eur_liter  \
# 0               1.26719             1.45732                 NaN
# 1               1.24115             1.44331                 NaN
# 2               1.24210             1.43745                 NaN
# 3               1.25581             1.44560                 NaN
# 4               1.25613             1.44767                 NaN
#
#    Brent_usd_barrel  Eur_usd  Brent_eur_barrel  BRENT_eur_liter
# 0               NaN      NaN               NaN              NaN
# 1               NaN      NaN               NaN              NaN
# 2             94.84   1.3358         70.998652          0.44657
# 3             93.53   1.3357         70.023209          0.44043
# 4             95.50   1.3321         71.691314          0.45093
# df_clean len= 365
#         Date  Gas_E10_eur_liter  Gas_E85_eur_liter  Gas_GPLC_eur_liter  \
# 0 2011-01-01            1.43855            0.85000             0.82688
# 1 2011-01-02            1.49219            0.85000             0.81986
# 2 2011-01-03            1.41594            0.83884             0.78407
# 3 2011-01-04            1.44049            0.84095             0.82073
# 4 2011-01-05            1.45294            0.84484             0.82335
# 5 2011-01-06            1.43344            0.84242             0.79975
# 6 2011-01-07            1.43904            0.84372             0.80936
# 7 2011-01-08            1.46341            0.83868             0.81412
# 8 2011-01-09            1.47230            0.85375             0.81400
# 9 2011-01-10            1.43708            0.84484             0.81353
#
#    Gas_GAZOLE_eur_liter  Gas_SP95_eur_liter  Gas_SP98_eur_liter  \
# 0               1.26719             1.45732                 NaN
# 1               1.24115             1.44331                 NaN
# 2               1.24210             1.43745                 NaN
# 3               1.25581             1.44560                 NaN
# 4               1.25613             1.44767                 NaN
# 5               1.25275             1.44424                 NaN
# 6               1.26012             1.45426                 NaN
# 7               1.26526             1.45483                 NaN
# 8               1.26932             1.46064                 NaN
# 9               1.26120             1.45654                 NaN
#
#    BRENT_eur_liter
# 0              NaN
# 1              NaN
# 2          0.44657
# 3          0.44043
# 4          0.45093
# 5          0.45186
# 6          0.45226
# 7              NaN
# 8              NaN
# 9          0.46680
# correctly loaded 2011 denormalized datas to MongoDB
# YEAR:  2012  // start_date: 2012-01-01 00:00:00 end_date: 2013-01-01 00:00:00
# df_french_gas_station
# Gas_name       Date  Gas_E10_eur_liter  Gas_E85_eur_liter  Gas_GPLC_eur_liter  \
# 0        
#
#    Gas_GAZOLE_eur_liter  Gas_SP95_eur_liter  Gas_SP98_eur_liter  \
# 0               1.43988             1.55644                 NaN
# 1               1.36495             1.51323                 NaN
# 2               1.37291             1.51695                 NaN
# 3               1.37960             1.52390                 NaN
# 4               1.39243             1.53108                 NaN
# 5               1.40025             1.53956                 NaN
# 6               1.39953             1.54030                 NaN
# 7               1.40345             1.54320                 NaN
# 8               1.39861             1.54588                 NaN
# 9               1.40953             1.55245                 NaN
#
#    BRENT_eur_liter
# 0              NaN
# 1              NaN
# 2          0.54499
# 3          0.54776
# 4          0.54838
# 5          0.55574
# 6              NaN
# 7              NaN
# 8          0.55780
# 9          0.55769
# correctly loaded 2012 denormalized datas to MongoDB
# YEAR:  2013  // start_date: 2013-01-01 00:00:00 end_date: 2014-01-01 00:00:00
# df_french_gas_station
# Gas_name       Date  Gas_E10_eur_liter  Gas_E85_eur_liter  Gas_GPLC_eur_liter  \
# 0        2013-01-01            1.46829            0.94929             0.93813
# 1        2013-01-02            1.47276            0.92526             0.86400
# 2        2013-01-03            1.50348            0.93361             0.87958
# 3        2013-01-04            1.50624            0.93130             0.88060
# 4        2013-01-05            1.52166            0.92733             0.87512
#
# Gas_name  Gas_GAZOLE_eur_liter  Gas_SP95_eur_liter  Gas_SP98_eur_liter
# 0                      1.34179             1.58390                 NaN
# 1                      1.34186             1.51233                 NaN
# 2                      1.34925             1.51556                 NaN
# 3                      1.35424             1.52499                 NaN
# 4                      1.35351             1.52556                 NaN
# stockmarket_brent_usd
#         Date  Brent_usd_barrel
# 0 2013-01-02            112.47
# 1 2013-01-03            112.14
# 2 2013-01-04            111.31
# 3 2013-01-07            111.40
# 4 2013-01-08            111.94
# stockmarket_eur_usd
#         Date  Eur_usd
# 0 2013-01-01   1.3201
# 1 2013-01-02   1.3198
# 2 2013-01-03   1.3182
# 3 2013-01-04   1.3033
# 4 2013-01-07   1.3067
# df_result after all the joined
#         Date  Gas_E10_eur_liter  Gas_E85_eur_liter  Gas_GPLC_eur_liter  \
# 0 2013-01-01            1.46829            0.94929             0.93813
# 1 2013-01-02            1.47276            0.92526             0.86400
# 2 2013-01-03            1.50348            0.93361             0.87958
# 3 2013-01-04            1.50624            0.93130             0.88060
# 4 2013-01-05            1.52166            0.92733             0.87512
#
#    Gas_GAZOLE_eur_liter  Gas_SP95_eur_liter  Gas_SP98_eur_liter  \
# 0               1.34179             1.58390                 NaN
# 1               1.34186             1.51233                 NaN
# 2               1.34925             1.51556                 NaN
# 3               1.35424             1.52499                 NaN
# 4               1.35351             1.52556                 NaN
#
#    Brent_usd_barrel  Eur_usd
# 0               NaN   1.3201
# 1            112.47   1.3198
# 2            112.14   1.3182
# 3            111.31   1.3033
# 4               NaN      NaN
# df_result after create BRENT_eur_liter
#         Date  Gas_E10_eur_liter  Gas_E85_eur_liter  Gas_GPLC_eur_liter  \
# 0 2013-01-01            1.46829            0.94929             0.93813
# 1 2013-01-02            1.47276            0.92526             0.86400
# 2 2013-01-03            1.50348            0.93361             0.87958
# 3 2013-01-04            1.50624            0.93130             0.88060
# 4 2013-01-05            1.52166            0.92733             0.87512
#
#    Gas_GAZOLE_eur_liter  Gas_SP95_eur_liter  Gas_SP98_eur_liter  \
# 0               1.34179             1.58390                 NaN
# 1               1.34186             1.51233                 NaN
# 2               1.34925             1.51556                 NaN
# 3               1.35424             1.52499                 NaN
# 4               1.35351             1.52556                 NaN
#
#    Brent_usd_barrel  Eur_usd  Brent_eur_barrel  BRENT_eur_liter
# 0               NaN   1.3201               NaN              NaN
# 1            112.47   1.3198         85.217457          0.53600
# 2            112.14   1.3182         85.070551          0.53508
# 3            111.31   1.3033         85.406276          0.53719
# 4               NaN      NaN               NaN              NaN
# df_clean len= 365
#         Date  Gas_E10_eur_liter  Gas_E85_eur_liter  Gas_GPLC_eur_liter  \
# 0 2013-01-01            1.46829            0.94929             0.93813
# 1 2013-01-02            1.47276            0.92526             0.86400
# 2 2013-01-03            1.50348            0.93361             0.87958
# 3 2013-01-04            1.50624            0.93130             0.88060
# 4 2013-01-05            1.52166            0.92733             0.87512
# 5 2013-01-06            1.55353            0.94864             0.91247
# 6 2013-01-07            1.49682            0.93381             0.86340
# 7 2013-01-08            1.52258            0.94198             0.87269
# 8 2013-01-09            1.51494            0.92788             0.87135
# 9 2013-01-10            1.53118            0.93707             0.87749
#
#    Gas_GAZOLE_eur_liter  Gas_SP95_eur_liter  Gas_SP98_eur_liter  \
# 0               1
#         Date  Gas_E10_eur_liter  Gas_E85_eur_liter  Gas_GPLC_eur_liter  \
# 0 2025-01-01            1.75098            0.79343             1.00802
# 1 2025-01-02            1.73692            0.78582             1.00151
# 2 2025-01-03            1.74349            0.79075             1.01011
# 3 2025-01-04            1.75123            0.79112             1.00917
# 4 2025-01-05            1.76463            0.79195             1.01206
#
#    Gas_GAZOLE_eur_liter  Gas_SP95_eur_liter  Gas_SP98_eur_liter  \
# 0               1.68511             1.77197             1.86130
# 1               1.66950             1.77162             1.84131
# 2               1.67498             1.77232             1.84697
# 3               1.68353             1.76892             1.85840
# 4               1.69999             1.77121             1.87177
#
#    Brent_usd_barrel  Eur_usd
# 0               NaN      NaN
# 1             75.93   1.0352
# 2             76.51   1.0268
# 3               NaN      NaN
# 4               NaN      NaN
# df_result after create BRENT_eur_liter
#         Date  Gas_E10_eur_liter  Gas_E85_eur_liter  Gas_GPLC_eur_liter  \
# 0 2025-01-01            1.75098            0.79343             1.00802
# 1 2025-01-02            1.73692            0.78582             1.00151
# 2 2025-01-03            1.74349            0.79075             1.01011
# 3 2025-01-04            1.75123            0.79112             1.00917
# 4 2025-01-05            1.76463            0.79195             1.01206
#
#    Gas_GAZOLE_eur_liter  Gas_SP95_eur_liter  Gas_SP98_eur_liter  \
# 0               1.68511             1.77197             1.86130
# 1               1.66950             1.77162             1.84131
# 2               1.67498             1.77232             1.84697
# 3               1.68353             1.76892             1.85840
# 4               1.69999             1.77121             1.87177
#
#    Brent_usd_barrel  Eur_usd  Brent_eur_barrel  BRENT_eur_liter
# 0               NaN      NaN               NaN              NaN
# 1             75.93   1.0352         73.348145          0.46135
# 2             76.51   1.0268         74.513050          0.46867
# 3               NaN      NaN               NaN              NaN
# 4               NaN      NaN               NaN              NaN
# df_clean len= 159
#         Date  Gas_E10_eur_liter  Gas_E85_eur_liter  Gas_GPLC_eur_liter  \
# 0 2025-01-01            1.75098            0.79343             1.00802
# 1 2025-01-02            1.73692            0.78582             1.00151
# 2 2025-01-03            1.74349            0.79075             1.01011
# 3 2025-01-04            1.75123            0.79112             1.00917
# 4 2025-01-05            1.76463            0.79195             1.01206
# 5 2025-01-06            1.74618            0.78951             1.00481
# 6 2025-01-07            1.75845            0.79650             1.01190
# 7 2025-01-08            1.75947            0.79423             1.00790
# 8 2025-01-09            1.76237            0.79199             1.00775
# 9 2025-01-10            1.76039            0.79185             1.00846
#
#    Gas_GAZOLE_eur_liter  Gas_SP95_eur_liter  Gas_SP98_eur_liter  \
# 0               1.68511             1.77197             1.86130
# 1               1.66950             1.77162             1.84131
# 2               1.67498             1.77232             1.84697
# 3               1.68353             1.76892             1.85840
# 4               1.69999             1.77121             1.87177
# 5               1.68088             1.78349             1.84857
# 6               1.69159             1.78865             1.86346
# 7               1.69188             1.78150             1.86225
# 8               1.69412             1.78528             1.86565
# 9               1.69436             1.78862             1.86487
#
#    BRENT_eur_liter
# 0              NaN
# 1          0.46135
# 2          0.46867
# 3              NaN
# 4              NaN
# 5          0.46571
# 6          0.46662
# 7          0.46301
# 8          0.46904
# 9          0.48716
# correctly loaded 2025 denormalized datas to MongoDB
