# %%
import pandas as pd
import os
import warnings
import pymongo
import json
import datetime

pd.options.mode.chained_assignment = None
warnings.filterwarnings('ignore', category=RuntimeWarning)

# Setup MongoDB connection (local)
mongo_host = "localhost"
mongo_port = 27017
mongo_user = "admin"
mongo_password = "password"
auth_db = "admin"
client_mongo = pymongo.MongoClient(
    host=mongo_host,
    port=mongo_port,
    username=mongo_user,
    password=mongo_password,
    authSource=auth_db
)
db_mongo = client_mongo.get_database("datalake")

# Supprimer la collection si elle existe
db_mongo.drop_collection("french_gas_station")

collection_mongo = db_mongo.get_collection("french_gas_station")
collection_mongo.create_index([("Date", pymongo.ASCENDING), ("Nom", pymongo.ASCENDING)])

# ALL YEARS
years = ['2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022', '2023', '2024', '2025']
#years = ['2007', '2008', '2009', '2010', '2011', '2012']
# ONE YEAR
#years = ['2007']

for year in years:
    print("YEAR: ", year)
    
    file_path = f"results/inputs_csv_zscore_last/PrixCarburants_annuel_filtered_{year}.csv"
    
    if not os.path.exists(file_path):
        print(f"Le fichier {file_path} n'existe pas.")
    else:
        df = pd.read_csv(file_path)
        print("len = ", len(df))
        df['date'] = pd.to_datetime(df['date'], format='%Y_%m_%d')
        df['heuremin'] = pd.to_datetime(df['heuremin'], format='%H:%M').dt.strftime('%H:%M:%S')
        df['valeur'] = df['valeur']*0.001
        
        df.columns = [col.capitalize() for col in df.columns]
        print(df.head(5))
        print(df.dtypes)
        
        records = df.to_dict(orient="records")
        collection_mongo.insert_many(records)
        print("correctly loaded", year, "csv to MongoDB")
# Out:
# YEAR:  2007
# len =  651116
#         Date     Nom   Latitude  Longitude    Cp                  Ville  \
# 0 2007-01-04  Gazole  4620114.0   519791.0  1000  SAINT-DENIS-LèS-BOURG
# 1 2007-01-04    SP95  4620114.0   519791.0  1000  SAINT-DENIS-LèS-BOURG
# 2 2007-01-09  Gazole  4620114.0   519791.0  1000  SAINT-DENIS-LèS-BOURG
# 3 2007-01-09    SP95  4620114.0   519791.0  1000  SAINT-DENIS-LèS-BOURG
# 4 2007-01-12  Gazole  4620114.0   519791.0  1000  SAINT-DENIS-LèS-BOURG
#
#            Adresse  Valeur  Heuremin  Gas_station_id
# 0  ROUTE NATIONALE   0.999  18:43:00         1000001
# 1  ROUTE NATIONALE   1.170  18:43:00         1000001
# 2  ROUTE NATIONALE   0.999  08:32:00         1000001
# 3  ROUTE NATIONALE   1.160  08:32:00         1000001
# 4  ROUTE NATIONALE   0.989  08:42:00         1000001
# Date              datetime64[ns]
# Nom                       object
# Latitude                 float64
# Longitude                float64
# Cp                         int64
# Ville                     object
# Adresse                   object
# Valeur                   float64
# Heuremin                  object
# Gas_station_id             int64
# dtype: object
# correctly loaded 2007 csv to MongoDB
# YEAR:  2008
# len =  997061
#         Id       Date     Nom   Latitude  Longitude    Cp  \
# 0  1000001 2008-01-04  Gazole  4620114.0   519791.0  1000
# 1  1000001 2008-01-04    SP95  4620114.0   519791.0  1000
# 2  1000001 2008-01-07  Gazole  4620114.0   519791.0  1000
# 3  1000001 2008-01-08    SP95  4620114.0   519791.0  1000
# 4  1000001 2008-01-15  Gazole  4620114.0   519791.0  1000
#
#                    Ville          Adresse  Valeur  Heuremin
# 0  SAINT-DENIS-LèS-BOURG  ROUTE NATIONALE   1.189  08:50:00
# 1  SAINT-DENIS-LèS-BOURG  ROUTE NATIONALE   1.339  08:50:00
# 2  SAINT-DENIS-LèS-BOURG  ROUTE NATIONALE   1.199  10:18:00
# 3  SAINT-DENIS-LèS-BOURG  ROUTE NATIONALE   1.359  10:38:00
# 4  SAINT-DENIS-LèS-BOURG  ROUTE NATIONALE   1.179  08:39:00
# Id                    int64
# Date         datetime64[ns]
# Nom                  object
# Latitude            float64
# Longitude           float64
# Cp                    int64
# Ville                object
# Adresse              object
# Valeur              float64
# Heuremin             object
# dtype: object
# correctly loaded 2008 csv to MongoDB
# YEAR:  2009
# len =  1023922
#         Id       Date     Nom   Latitude  Longitude    Cp  \
# 0  1000001 2009-01-05  Gazole  4620114.0   519791.0  1000
# 1  1000001 2009-01-05    SP95  4620114.0   519791.0  1000
# 2  1000001 2009-01-10  Gazole  4620114.0   519791.0  1000
# 3  1000001 2009-01-10    SP95  4620114.0   519791.0  1000
# 4  1000001 2009-01-16  Gazole  4620114.0   519791.0  1000
#
#                    Ville          Adresse  Valeur  Heuremin
# 0  SAINT-DENIS-LèS-BOURG  ROUTE NATIONALE   0.909  08:53:00
# 1  SAINT-DENIS-LèS-BOURG  ROUTE NATIONALE   1.022  08:53:00
# 2  SAINT-DENIS-LèS-BOURG  ROUTE NATIONALE   0.965  08:58:00
# 3  SAINT-DENIS-LèS-BOURG  ROUTE NATIONALE   1.089  08:58:00
# 4  SAINT-DENIS-LèS-BOURG  ROUTE NATIONALE   0.965  09:37:00
# Id                    int64
# Date         datetime64[ns]
# Nom                  object
# Latitude            float64
# Longitude           float64
# Cp                    int64
# Ville                object
# Adresse              object
# Valeur              float64
# Heuremin             object
# dtype: object
# correctly loaded 2009 csv to MongoDB
# YEAR:  2010
# len =  1055085
#         Id       Date     Nom   Latitude  Longitude    Cp  \
# 0  1000001 2010-01-02  Gazole  4620114.0   519791.0  1000
# 1  1000001 2010-01-02    SP95  4620114.0   519791.0  1000
# 2  1000001 2010-01-05    SP95  4620114.0   519791.0  1000
# 3  1000001 2010-01-06    SP95  4620114.0   519791.0  1000
# 4  1000001 2010-01-08  Gazole  4620114.0   519791.0  1000
#
#                    Ville          Adresse  Valeur  Heuremin
# 0  SAINT-DENIS-LèS-BOURG  ROUTE NATIONALE   1.018  08:28:00
# 1  SAINT-DENIS-LèS-BOURG  ROUTE NATIONALE   1.242  08:28:00
# 2  SAINT-DENIS-LèS-BOURG  ROUTE NATIONALE   1.258  09:51:00
# 3  SAINT-DENIS-LèS-BOURG  ROUTE NATIONALE   1.269  19:07:00
# 4  SAINT-DENIS-LèS-BOURG  ROUTE NATIONALE   1.045  10:28:00
# Id                    int64
# Date         datetime64[ns]
# Nom                  object
# Latitude            float64
# Longitude           float64
# Cp                    int64
# Ville                object
# Adresse              object
# Valeur              float64
# Heuremin             object
# dtype: object
# correctly loaded 2010 csv to MongoDB
# YEAR:  2011
# len =  1124064
#         Id       Date     Nom   Latitude  Longitude    Cp  \
# 0  1000001 2011-01-06    SP95  4620114.0   519791.0  1000
# 1  1000001 2011-01-18    SP95  4620114.0   519791.0  1000
# 2  1000001 2011-01-19  Gazole  4620114.0   519791.0  1000
# 3  1000001 2011-01-19    SP95  4620114.0   519791.0  1000
# 4  1000001 2011-01-28  Gazole  4620114.0   519791.0  1000
#
#                    Ville          Adresse  Valeur  Heuremin
# 0  SAINT-DENIS-LèS-BOURG  ROUTE NATIONALE   1.415  09:28:00
# 1  SAINT-DENIS-LèS-BOURG  ROUTE NATIONALE   1.442  08:59:00
# 2  SAINT-DENIS-LèS-BOURG  ROUTE NATIONALE   1.245  09:11:00
# 3  SAINT-DENIS-LèS-BOURG  ROUTE NATIONALE   1.445  09:11:00
# 4  SAINT-DENIS-LèS-BOURG  ROUTE NATIONALE   1.245  09:03:00
# Id                    int64
# Date         datetime64[ns]
# Nom                  object
# Latitude            float64
# Longitude           float64
# Cp                    int64
# Ville                object
# Adresse              object
# Valeur              float64
# Heuremin             object
# dtype: object
# correctly loaded 2011 csv to MongoDB
# YEAR:  2012
# len =  1262773
#         Id       Date     Nom   Latitude  Longitude    Cp  \
# 0  1000001 2012-01-03    SP95  4620114.0   519791.0  1000
# 1  1000001 2012-01-05    SP95  4620114.0   519791.0  1000
# 2  1000001 2012-01-06    SP95  4620114.0   519791.0  1000
# 3  1000001 2012-01-07    SP95  4620114.0   519791.0  1000
# 4  1000001 2012-01-19  Gazole  4620114.0   519791.0  1000
#
#                    Ville          Adresse  Valeur  Heuremin
# 0  SAINT-DENIS-LèS-BOURG  ROUTE NATIONALE   1.475  09:25:00
# 1  SAINT-DENIS-LèS-BOURG  ROUTE NATIONALE   1.499  10:50:00
# 2  SAINT-DENIS-LèS-BOURG  ROUTE NATIONALE   1.505  10:01:00
# 3  SAINT-DENIS-LèS-BOURG  ROUTE NATIONALE   1.519  09:29:00
# 4  SAINT-DENIS-LèS-BOURG  ROUTE NATIONALE   1.379  09:57:00
# Id                    int64
# Date         datetime64[ns]
# Nom                  object
# Latitude            float64
# Longitude           float64
# Cp                    int64
# Ville                object
# Adresse              object
# Valeur              float64
# Heuremin             object
# dtype: object
# correctly loaded 2012 csv to MongoDB
# YEAR:  2013
# len =  1500552
#         Id       Date     Nom   Latitude  Longitude    Cp  \
# 0  1000001 2013-01-07    SP95  4620114.0   519791.0  1000
# 1  1000001 2013-01-18    SP95  4620114.0   519791.0  1000
# 2  1000001 2013-01-20    SP95  4620114.0   519791.0  1000
# 3  1000001 2013-01-21  Gazole  4620114.0   519791.0  1000
# 4  1000001 2013-01-21    SP95  4620114.0   519791.0  1000
#
#                    Ville          Adresse  Valeur  Heuremin
# 0  SAINT-DENIS-LèS-BOURG  ROUTE NATIONALE   1.499  09:30:00
# 1  SAINT-DENIS-LèS-BOURG  ROUTE NATIONALE   1.529  11:31:00
# 2  SAINT-DENIS-LèS-BOURG  ROUTE NATIONALE   1.529  10:19:00
# 3  SAINT-DENIS-LèS-BOURG  ROUTE NATIONALE   1.339  09:23:00
# 4  SAINT-DENIS-LèS-BOURG  ROUTE NATIONALE   1.529  09:23:00
# Id                    int64
# Date         datetime64[ns]
# Nom                  object
# Latitude            float64
# Longitude           float64
# Cp                    int64
# Ville                object
# Adresse              object
# Valeur              float64
# Heuremin             object
# dtype: object
# correctly loaded 2013 csv to MongoDB
# YEAR:  2014
# len =  1596921
#         Id       Date     Nom   Latitude  Longitude    Cp  \
# 0  1000001 2014-01-02  Gazole  4620114.0   519791.0  1000
# 1  1000001 2014-01-02    SP95  4620114.0   519791.0  1000
# 2  1000001 2014-01-02    SP98  4620114.0   519791.0  1000
# 3  1000001 2014-01-04  Gazole  4620114.0   519791.0  1000
# 4  1000001 2014-01-04    SP95  4620114.0   519791.0  1000
#
#                    Ville          Adresse  Valeur  Heuremin
# 0  SAINT-DENIS-LèS-BOURG  ROUTE NATIONALE   1.304  11:08:00
# 1  SAINT-DENIS-LèS-BOURG  ROUTE NATIONALE   1.499  11:08:00
# 2  SAINT-DENIS-LèS-BOURG  ROUTE NATIONALE   1.535  11:08:00
# 3  SAINT-DENIS-LèS-BOURG  ROUTE NATIONALE   1.304  09:54:00
# 4  SAINT-DENIS-LèS-BOURG  ROUTE NATIONALE   1.499  09:54:00
# Id                    int64
# Date         datetime64[ns]
# Nom                  object
# Latitude            float64
# Longitude           float64
# Cp                    int64
# Ville                object
# Adresse              object
# Valeur              float64
# Heuremin             object
# dtype: object
# correctly loaded 2014 csv to MongoDB
# YEAR:  2015
# len =  2270285
#         Id       Date     Nom   Latitude  Longitude    Cp  \
# 0  1000001 2015-01-02  Gazole  4620114.0   519791.0  1000
# 1  1000001 2015-01-02    SP95  4620114.0   519791.0  1000
# 2  1000001 2015-01-02    SP98  4620114.0   519791.0  1000
# 3  1000001 2015-01-03  Gazole  4620114.0   519791.0  1000
# 4  1000001 2015-01-03    SP95  4620114.0   519791.0  1000
#
#                    Ville                Adresse  Valeur  Heuremin
# 0  SAINT-DENIS-LèS-BOURG  596 AVENUE DE TREVOUX   1.141  11:01:00
# 1  SAINT-DENIS-LèS-BOURG  596 AVENUE DE TREVOUX   1.311  11:01:00
# 2  SAINT-DENIS-LèS-BOURG  596 AVENUE DE TREVOUX   1.327  11:01:00
# 3  SAINT-DENIS-LèS-BOURG  596 AVENUE DE TREVOUX   1.141  09:01:00
# 4  SAINT-DENIS-LèS-BOURG  596 AVENUE DE TREVOUX   1.311  09:01:00
# Id                    int64
# Date         datetime64[ns]
# Nom                  object
# Latitude            float64
# Longitude           float64
# Cp                    int64
# Ville                object
# Adresse              object
# Valeur              float64
# Heuremin             object
# dtype: object
# correctly loaded 2015 csv to MongoDB
# YEAR:  2016
# len =  2629396
#         Id       Date     Nom   Latitude  Longitude    Cp  \
# 0  1000001 2016-01-02  Gazole  4620114.0   519791.0  1000
# 1  1000001 2016-01-02    SP95  4620114.0   519791.0  1000
# 2  1000001 2016-01-02    SP98  4620114.0   519791.0  1000
# 3  1000001 2016-01-04  Gazole  4620114.0   519791.0  1000
# 4  1000001 2016-01-04    SP95  4620114.0   519791.0  1000
#
#                    Ville                Adresse  Valeur  Heuremin
# 0  SAINT-DENIS-LèS-BOURG  596 AVENUE DE TREVOUX   1.026  09:01:00
# 1  SAINT-DENIS-LèS-BOURG  596 AVENUE DE TREVOUX   1.294  09:01:00
# 2  SAINT-DENIS-LèS-BOURG  596 AVENUE DE TREVOUX   1.315  09:01:00
# 3  SAINT-DENIS-LèS-BOURG  596 AVENUE DE TREVOUX   1.026  12:01:00
# 4  SAINT-DENIS-LèS-BOURG  596 AVENUE DE TREVOUX   1.294  12:01:00
# Id                    int64
# Date         datetime64[ns]
# Nom                  object
# Latitude            float64
# Longitude           float64
# Cp                    int64
# Ville                object
# Adresse              object
# Valeur              float64
# Heuremin             object
# dtype: object
# correctly loaded 2016 csv to MongoDB
# YEAR:  2017
# len =  2528401
#         Id       Date     Nom   Latitude  Longitude    Cp  \
# 0  1000001 2017-01-02  Gazole  4620114.0   519791.0  1000
# 1  1000001 2017-01-02    SP95  4620114.0   519791.0  1000
# 2  1000001 2017-01-02    SP98  4620114.0   519791.0  1000
# 3  1000001 2017-01-03  Gazole  4620114.0   519791.0  1000
# 4  1000001 2017-01-03    SP95  4620114.0   519791.0  1000
#
#                    Ville                Adresse  Valeur  Heuremin
# 0  SAINT-DENIS-LèS-BOURG  596 AVENUE DE TREVOUX   1.258  09:37:00
# 1  SAINT-DENIS-LèS-BOURG  596 AVENUE DE TREVOUX   1.409  09:37:00
# 2  SAINT-DENIS-LèS-BOURG  596 AVENUE DE TREVOUX   1.441  09:37:00
# 3  SAINT-DENIS-LèS-BOURG  596 AVENUE DE TREVOUX   1.258  09:54:00
# 4  SAINT-DENIS-LèS-BOURG  596 AVENUE DE TREVOUX   1.409  09:54:00
# Id                    int64
# Date         datetime64[ns]
# Nom                  object
# Latitude            float64
# Longitude           float64
# Cp                    int64
# Ville                object
# Adresse              object
# Valeur              float64
# Heuremin             object
# dtype: object
# correctly loaded 2017 csv to MongoDB
# YEAR:  2018
# len =  2678794
#         Id       Date     Nom   Latitude  Longitude    Cp  \
# 0  1000001 2018-01-06  Gazole  4620114.0   519791.0  1000
# 1  1000001 2018-01-06    SP95  4620114.0   519791.0  1000
# 2  1000001 2018-01-06    SP98  4620114.0   519791.0  1000
# 3  1000001 2018-01-11  Gazole  4620114.0   519791.0  1000
# 4  1000001 2018-01-11    SP95  4620114.0   519791.0  1000
#
#                    Ville                Adresse  Valeur  Heuremin
# 0  SAINT-DENIS-LèS-BOURG  596 AVENUE DE TREVOUX   1.376  12:20:00
# 1  SAINT-DENIS-LèS-BOURG  596 AVENUE DE TREVOUX   1.463  12:20:00
# 2  SAINT-DENIS-LèS-BOURG  596 AVENUE DE TREVOUX   1.523  12:20:00
# 3  SAINT-DENIS-LèS-BOURG  596 AVENUE DE TREVOUX   1.389  09:09:00
# 4  SAINT-DENIS-LèS-BOURG  596 AVENUE DE TREVOUX   1.474  09:09:00
# Id                    int64
# Date         datetime64[ns]
# Nom                  object
# Latitude            float64
# Longitude           float64
# Cp                    int64
# Ville                object
# Adresse              object
# Valeur              float64
# Heuremin             object
# dtype: object
# correctly loaded 2018 csv to MongoDB
# YEAR:  2019
# len =  2814906
#         Id       Date     Nom   Latitude  Longitude    Cp  \
# 0  1000001 2019-01-04  Gazole  4620114.0   519791.0  1000
# 1  1000001 2019-01-04    SP95  4620114.0   519791.0  1000
# 2  1000001 2019-01-07  Gazole  4620114.0   519791.0  1000
# 3  1000001 2019-01-07    SP95  4620114.0   519791.0  1000
# 4  1000001 2019-01-07    SP98  4620114.0   519791.0  1000
#
#                    Ville                Adresse  Valeur  Heuremin
# 0  SAINT-DENIS-LèS-BOURG  596 AVENUE DE TREVOUX   1.328  10:53:00
# 1  SAINT-DENIS-LèS-BOURG  596 AVENUE DE TREVOUX   1.375  10:53:00
# 2  SAINT-DENIS-LèS-BOURG  596 AVENUE DE TREVOUX   1.348  10:25:00
# 3  SAINT-DENIS-LèS-BOURG  596 AVENUE DE TREVOUX   1.387  10:25:00
# 4  SAINT-DENIS-LèS-BOURG  596 AVENUE DE TREVOUX   1.409  10:25:00
# Id                    int64
# Date         datetime64[ns]
# Nom                  object
# Latitude            float64
# Longitude           float64
# Cp                    int64
# Ville                object
# Adresse              object
# Valeur              float64
# Heuremin             object
# dtype: object
# correctly loaded 2019 csv to MongoDB
# YEAR:  2020
# len =  2612777
#         Id       Date     Nom   Latitude  Longitude    Cp  \
# 0  1000001 2020-01-03  Gazole  4620114.0   519791.0  1000
# 1  1000001 2020-01-06  Gazole  4620114.0   519791.0  1000
# 2  1000001 2020-01-07  Gazole  4620114.0   519791.0  1000
# 3  1000001 2020-01-07    SP95  4620114.0   519791.0  1000
# 4  1000001 2020-01-11    SP95  4620114.0   519791.0  1000
#
#                    Ville                Adresse  Valeur  Heuremin
# 0  SAINT-DENIS-LèS-BOURG  596 AVENUE DE TREVOUX   1.442  10:36:00
# 1  SAINT-DENIS-LèS-BOURG  596 AVENUE DE TREVOUX   1.443  10:36:00
# 2  SAINT-DENIS-LèS-BOURG  596 AVENUE DE TREVOUX   1.458  10:48:00
# 3  SAINT-DENIS-LèS-BOURG  596 AVENUE DE TREVOUX   1.525  10:48:00
# 4  SAINT-DENIS-LèS-BOURG  596 AVENUE DE TREVOUX   1.530  10:15:00
# Id                    int64
# Date         datetime64[ns]
# Nom                  object
# Latitude            float64
# Longitude           float64
# Cp                    int64
# Ville                object
# Adresse              object
# Valeur              float64
# Heuremin             object
# dtype: object
# correctly loaded 2020 csv to MongoDB
# YEAR:  2021
# len =  2978090
#         Id       Date     Nom   Latitude  Longitude    Cp  \
# 0  1000001 2021-01-02  Gazole  4620114.0   519791.0  1000
# 1  1000001 2021-01-02    SP95  4620114.0   519791.0  1000
# 2  1000001 2021-01-02    SP98  4620114.0   519791.0  1000
# 3  1000001 2021-01-04  Gazole  4620114.0   519791.0  1000
# 4  1000001 2021-01-06  Gazole  4620114.0   519791.0  1000
#
#                    Ville                Adresse  Valeur  Heuremin
# 0  SAINT-DENIS-LèS-BOURG  596 AVENUE DE TREVOUX   1.252  15:13:00
# 1  SAINT-DENIS-LèS-BOURG  596 AVENUE DE TREVOUX   1.374  15:13:00
# 2  SAINT-DENIS-LèS-BOURG  596 AVENUE DE TREVOUX   1.399  15:13:00
# 3  SAINT-DENIS-LèS-BOURG  596 AVENUE DE TREVOUX   1.268  09:28:00
# 4  SAINT-DENIS-LèS-BOURG  596 AVENUE DE TREVOUX   1.268  15:45:00
# Id                    int64
# Date         datetime64[ns]
# Nom                  object
# Latitude            float64
# Longitude           float64
# Cp                    int64
# Ville                object
# Adresse              object
# Valeur              float64
# Heuremin             object
# dtype: object
# correctly loaded 2021 csv to MongoDB
# YEAR:  2022
# len =  3557376
#         Id       Date     Nom   Latitude  Longitude    Cp  \
# 0  1000001 2022-01-03  Gazole  4620100.0   519800.0  1000
# 1  1000001 2022-01-03    SP95  4620100.0   519800.0  1000
# 2  1000001 2022-01-03    SP98  4620100.0   519800.0  1000
# 3  1000001 2022-01-05  Gazole  4620100.0   519800.0  1000
# 4  1000001 2022-01-05    SP95  4620100.0   519800.0  1000
#
#                    Ville                Adresse  Valeur  Heuremin
# 0  SAINT-DENIS-LèS-BOURG  596 AVENUE DE TREVOUX   1.572  08:44:00
# 1  SAINT-DENIS-LèS-BOURG  596 AVENUE DE TREVOUX   1.663  08:44:00
# 2  SAINT-DENIS-LèS-BOURG  596 AVENUE DE TREVOUX   1.694  08:44:00
# 3  SAINT-DENIS-LèS-BOURG  596 AVENUE DE TREVOUX   1.560  10:08:00
# 4  SAINT-DENIS-LèS-BOURG  596 AVENUE DE TREVOUX   1.653  10:08:00
# Id                    int64
# Date         datetime64[ns]
# Nom                  object
# Latitude            float64
# Longitude           float64
# Cp                    int64
# Ville                object
# Adresse              object
# Valeur              float64
# Heuremin             object
# dtype: object
# correctly loaded 2022 csv to MongoDB
# YEAR:  2023
# len =  3348441
#         Id       Date     Nom   Latitude  Longitude    Cp  \
# 0  1000001 2023-01-02  Gazole  4620100.0   519800.0  1000
# 1  1000001 2023-01-02    SP95  4620100.0   519800.0  1000
# 2  1000001 2023-01-05  Gazole  4620100.0   519800.0  1000
# 3  1000001 2023-01-05    SP95  4620100.0   519800.0  1000
# 4  1000001 2023-01-05    SP98  4620100.0   519800.0  1000
#
#                    Ville                Adresse  Valeur  Heuremin
# 0  SAINT-DENIS-LèS-BOURG  596 AVENUE DE TREVOUX   1.867  07:53:00
# 1  SAINT-DENIS-LèS-BOURG  596 AVENUE DE TREVOUX   1.800  07:53:00
# 2  SAINT-DENIS-LèS-BOURG  596 AVENUE DE TREVOUX   1.877  09:33:00
# 3  SAINT-DENIS-LèS-BOURG  596 AVENUE DE TREVOUX   1.832  09:33:00
# 4  SAINT-DENIS-LèS-BOURG  596 AVENUE DE TREVOUX   1.851  09:33:00
# Id                    int64
# Date         datetime64[ns]
# Nom                  object
# Latitude            float64
# Longitude           float64
# Cp                    int64
# Ville                object
# Adresse              object
# Valeur              float64
# Heuremin             object
# dtype: object
# correctly loaded 2023 csv to MongoDB
# YEAR:  2024
# len =  3200490
#         Id       Date     Nom   Latitude  Longitude    Cp  \
# 0  1000001 2024-01-02     E10  4620100.0   519800.0  1000
# 1  1000001 2024-01-02     E85  4620100.0   519800.0  1000
# 2  1000001 2024-01-02  Gazole  4620100.0   519800.0  1000
# 3  1000001 2024-01-02    SP95  4620100.0   519800.0  1000
# 4  1000001 2024-01-02    SP98  4620100.0   519800.0  1000
#
#                    Ville                Adresse  Valeur  Heuremin
# 0  SAINT-DENIS-LèS-BOURG  596 AVENUE DE TREVOUX   1.767  00:37:00
# 1  SAINT-DENIS-LèS-BOURG  596 AVENUE DE TREVOUX   0.961  00:37:00
# 2  SAINT-DENIS-LèS-BOURG  596 AVENUE DE TREVOUX   1.706  00:37:00
# 3  SAINT-DENIS-LèS-BOURG  596 AVENUE DE TREVOUX   1.801  00:37:00
# 4  SAINT-DENIS-LèS-BOURG  596 AVENUE DE TREVOUX   1.840  00:37:00
# Id                    int64
# Date         datetime64[ns]
# Nom                  object
# Latitude            float64
# Longitude           float64
# Cp                    int64
# Ville                object
# Adresse              object
# Valeur              float64
# Heuremin             object
# dtype: object
# correctly loaded 2024 csv to MongoDB
# YEAR:  2025
# len =  1526001
#         Id       Date     Nom   Latitude  Longitude    Cp  \
# 0  1000001 2025-01-02     E10  4620100.0   519800.0  1000
# 1  1000001 2025-01-02     E85  4620100.0   519800.0  1000
# 2  1000001 2025-01-02  Gazole  4620100.0   519800.0  1000
# 3  1000001 2025-01-02    SP95  4620100.0   519800.0  1000
# 4  1000001 2025-01-02    SP98  4620100.0   519800.0  1000
#
#                    Ville                Adresse  Valeur  Heuremin
# 0  SAINT-DENIS-LèS-BOURG  596 AVENUE DE TREVOUX   1.782  07:56:00
# 1  SAINT-DENIS-LèS-BOURG  596 AVENUE DE TREVOUX   0.758  07:56:00
# 2  SAINT-DENIS-LèS-BOURG  596 AVENUE DE TREVOUX   1.707  07:56:00
# 3  SAINT-DENIS-LèS-BOURG  596 AVENUE DE TREVOUX   1.824  07:56:00
# 4  SAINT-DENIS-LèS-BOURG  596 AVENUE DE TREVOUX   1.869  07:56:00
# Id                    int64
# Date         datetime64[ns]
# Nom                  object
# Latitude            float64
# Longitude           float64
# Cp                    int64
# Ville                object
# Adresse              object
# Valeur              float64
# Heuremin             object
# dtype: object
# correctly loaded 2025 csv to MongoDB
